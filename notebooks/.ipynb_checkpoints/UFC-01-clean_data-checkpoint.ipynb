# %% [markdown]
# # UFC-Fight historical data from 1993 to 2019
# https://www.kaggle.com/rajeevw/ufcdata
#
# https://github.com/WarrierRajeev/UFC-Predictions

# %% [markdown]
# ## Questions
# 1. Is data.csv calculated correctly?
#     1. Is the aggregate damage average correct?
#     1. Is the aggregated opponent average correct?
# 1. Who won the most fights?
# 1. What's the best age to win fights?
# 1. Who won the most title fights?
# 1. Which accuracy can be reached for the prediction of the winner?

# %% [markdown]
# # Get clean data

# %% [markdown]
# The way to go:
# 1. Examine the data
# 1. Handle missing values
# 1. Delete unneccesary data
# 1. Write an output file for further processing

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.impute import SimpleImputer

# %% [markdown]
# Use the partly preprocessed data source from kaggle.
# Don't aggregate the data for the previous fights ourselves.
#
# Random samples where recalculated in Excel to be sure they are correct.
# E.g. Henry Cejudo's first 3 fights.
# The work of Rajeev Warrier seems OK.

# %%
df = pd.read_csv("../data/raw/UFC/data.csv", sep=",")

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ## Examine the data

# %%
df.dtypes
# Out:
# R_fighter                        object
# B_fighter                        object
# Referee                          object
# date                             object
# location                         object
# Winner                           object
# title_bout                         bool
# weight_class                     object
# no_of_rounds                      int64
# B_current_lose_streak           float64
# B_current_win_streak            float64
# B_draw                          float64
# B_avg_BODY_att                  float64
# B_avg_BODY_landed               float64
# B_avg_CLINCH_att                float64
# B_avg_CLINCH_landed             float64
# B_avg_DISTANCE_att              float64
# B_avg_DISTANCE_landed           float64
# B_avg_GROUND_att                float64
# B_avg_GROUND_landed             float64
# B_avg_HEAD_att                  float64
# B_avg_HEAD_landed               float64
# B_avg_KD                        float64
# B_avg_LEG_att                   float64
# B_avg_LEG_landed                float64
# B_avg_PASS                      float64
# B_avg_REV                       float64
# B_avg_SIG_STR_att               float64
# B_avg_SIG_STR_landed            float64
# B_avg_SIG_STR_pct               float64
# B_avg_SUB_ATT                   float64
# B_avg_TD_att                    float64
# B_avg_TD_landed                 float64
# B_avg_TD_pct                    float64
# B_avg_TOTAL_STR_att             float64
# B_avg_TOTAL_STR_landed          float64
# B_longest_win_streak            float64
# B_losses                        float64
# B_avg_opp_BODY_att              float64
# B_avg_opp_BODY_landed           float64
# B_avg_opp_CLINCH_att            float64
# B_avg_opp_CLINCH_landed         float64
# B_avg_opp_DISTANCE_att          float64
# B_avg_opp_DISTANCE_landed       float64
# B_avg_opp_GROUND_att            float64
# B_avg_opp_GROUND_landed         float64
# B_avg_opp_HEAD_att              float64
# B_avg_opp_HEAD_landed           float64
# B_avg_opp_KD                    float64
# B_avg_opp_LEG_att               float64
# B_avg_opp_LEG_landed            float64
# B_avg_opp_PASS                  float64
# B_avg_opp_REV                   float64
# B_avg_opp_SIG_STR_att           float64
# B_avg_opp_SIG_STR_landed        float64
# B_avg_opp_SIG_STR_pct           float64
# B_avg_opp_SUB_ATT               float64
# B_avg_opp_TD_att                float64
# B_avg_opp_TD_landed             float64
# B_avg_opp_TD_pct                float64
# B_avg_opp_TOTAL_STR_att         float64
# B_avg_opp_TOTAL_STR_landed      float64
# B_total_rounds_fought           float64
# B_total_time_fought(seconds)    float64
# B_total_title_bouts             float64
# B_win_by_Decision_Majority      float64
# B_win_by_Decision_Split         float64
# B_win_by_Decision_Unanimous     float64
# B_win_by_KO/TKO                 float64
# B_win_by_Submission             float64
# B_win_by_TKO_Doctor_Stoppage    float64
# B_wins                          float64
# B_Stance                         object
# B_Height_cms                    float64
# B_Reach_cms                     float64
# B_Weight_lbs                    float64
# R_current_lose_streak           float64
# R_current_win_streak            float64
# R_draw                          float64
# R_avg_BODY_att                  float64
# R_avg_BODY_landed               float64
# R_avg_CLINCH_att                float64
# R_avg_CLINCH_landed             float64
# R_avg_DISTANCE_att              float64
# R_avg_DISTANCE_landed           float64
# R_avg_GROUND_att                float64
# R_avg_GROUND_landed             float64
# R_avg_HEAD_att                  float64
# R_avg_HEAD_landed               float64
# R_avg_KD                        float64
# R_avg_LEG_att                   float64
# R_avg_LEG_landed                float64
# R_avg_PASS                      float64
# R_avg_REV                       float64
# R_avg_SIG_STR_att               float64
# R_avg_SIG_STR_landed            float64
# R_avg_SIG_STR_pct               float64
# R_avg_SUB_ATT                   float64
# R_avg_TD_att                    float64
# R_avg_TD_landed                 float64
# R_avg_TD_pct                    float64
# R_avg_TOTAL_STR_att             float64
# R_avg_TOTAL_STR_landed          float64
# R_longest_win_streak            float64
# R_losses                        float64
# R_avg_opp_BODY_att              float64
# R_avg_opp_BODY_landed           float64
# R_avg_opp_CLINCH_att            float64
# R_avg_opp_CLINCH_landed         float64
# R_avg_opp_DISTANCE_att          float64
# R_avg_opp_DISTANCE_landed       float64
# R_avg_opp_GROUND_att            float64
# R_avg_opp_GROUND_landed         float64
# R_avg_opp_HEAD_att              float64
# R_avg_opp_HEAD_landed           float64
# R_avg_opp_KD                    float64
# R_avg_opp_LEG_att               float64
# R_avg_opp_LEG_landed            float64
# R_avg_opp_PASS                  float64
# R_avg_opp_REV                   float64
# R_avg_opp_SIG_STR_att           float64
# R_avg_opp_SIG_STR_landed        float64
# R_avg_opp_SIG_STR_pct           float64
# R_avg_opp_SUB_ATT               float64
# R_avg_opp_TD_att                float64
# R_avg_opp_TD_landed             float64
# R_avg_opp_TD_pct                float64
# R_avg_opp_TOTAL_STR_att         float64
# R_avg_opp_TOTAL_STR_landed      float64
# R_total_rounds_fought           float64
# R_total_time_fought(seconds)    float64
# R_total_title_bouts             float64
# R_win_by_Decision_Majority      float64
# R_win_by_Decision_Split         float64
# R_win_by_Decision_Unanimous     float64
# R_win_by_KO/TKO                 float64
# R_win_by_Submission             float64
# R_win_by_TKO_Doctor_Stoppage    float64
# R_wins                          float64
# R_Stance                         object
# R_Height_cms                    float64
# R_Reach_cms                     float64
# R_Weight_lbs                    float64
# B_age                           float64
# R_age                           float64
# dtype: object

# %%
df
# Out:
#                  R_fighter       B_fighter               Referee        date  \
# 0             Henry Cejudo   Marlon Moraes          Marc Goddard  2019-06-08
# 1     Valentina Shevchenko     Jessica Eye       Robert Madrigal  2019-06-08
# 2            Tony Ferguson  Donald Cerrone       Dan Miragliotta  2019-06-08
# 3            Jimmie Rivera        Petr Yan       Kevin MacDonald  2019-06-08
# 4              Tai Tuivasa   Blagoy Ivanov       Dan Miragliotta  2019-06-08
# ...                    ...             ...                   ...         ...
# 5139        Gerard Gordeau    Kevin Rosier  Joao Alberto Barreto  1993-11-12
# 5140          Ken Shamrock   Patrick Smith  Joao Alberto Barreto  1993-11-12
# 5141          Royce Gracie   Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142          Kevin Rosier    Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143        Gerard Gordeau      Teila Tuli  Joao Alberto Barreto  1993-11-12
#
#                     location Winner  title_bout       weight_class  \
# 0     Chicago, Illinois, USA    Red        True       Bantamweight
# 1     Chicago, Illinois, USA    Red        True  Women's Flyweight
# 2     Chicago, Illinois, USA    Red       False        Lightweight
# 3     Chicago, Illinois, USA   Blue       False       Bantamweight
# 4     Chicago, Illinois, USA   Blue       False        Heavyweight
# ...                      ...    ...         ...                ...
# 5139   Denver, Colorado, USA    Red       False        Open Weight
# 5140   Denver, Colorado, USA    Red       False        Open Weight
# 5141   Denver, Colorado, USA    Red       False        Open Weight
# 5142   Denver, Colorado, USA    Red       False        Open Weight
# 5143   Denver, Colorado, USA    Red       False        Open Weight
#
#       no_of_rounds  B_current_lose_streak  B_current_win_streak  B_draw  \
# 0                5                    0.0                   4.0     0.0
# 1                5                    0.0                   3.0     0.0
# 2                3                    0.0                   3.0     0.0
# 3                3                    0.0                   4.0     0.0
# 4                3                    0.0                   1.0     0.0
# ...            ...                    ...                   ...     ...
# 5139             1                    0.0                   1.0     0.0
# 5140             1                    0.0                   0.0     0.0
# 5141             1                    0.0                   0.0     0.0
# 5142             1                    0.0                   0.0     0.0
# 5143             1                    0.0                   0.0     0.0
#
#       B_avg_BODY_att  B_avg_BODY_landed  B_avg_CLINCH_att  \
# 0           9.200000           6.000000          0.200000
# 1          14.600000           9.100000         11.800000
# 2          15.354839          11.322581          6.741935
# 3          17.000000          14.000000         13.750000
# 4          17.000000          14.500000          2.500000
# ...              ...                ...               ...
# 5139        4.000000           3.000000          9.000000
# 5140             NaN                NaN               NaN
# 5141             NaN                NaN               NaN
# 5142             NaN                NaN               NaN
# 5143             NaN                NaN               NaN
#
#       B_avg_CLINCH_landed  B_avg_DISTANCE_att  B_avg_DISTANCE_landed  \
# 0                0.000000           62.600000              20.600000
# 1                7.300000          124.700000              42.100000
# 2                4.387097           84.741935              38.580645
# 3               11.000000          109.500000              48.750000
# 4                2.000000          201.000000              59.500000
# ...                   ...                 ...                    ...
# 5139             4.000000           10.000000               4.000000
# 5140                  NaN                 NaN                    NaN
# 5141                  NaN                 NaN                    NaN
# 5142                  NaN                 NaN                    NaN
# 5143                  NaN                 NaN                    NaN
#
#       B_avg_GROUND_att  B_avg_GROUND_landed  B_avg_HEAD_att  \
# 0             2.600000             2.000000       48.600000
# 1             2.400000             1.900000      112.000000
# 2             5.516129             3.806452       67.645161
# 3            13.000000            10.500000      116.250000
# 4             0.000000             0.000000      184.500000
# ...                ...                  ...             ...
# 5139          8.000000             7.000000       23.000000
# 5140               NaN                  NaN             NaN
# 5141               NaN                  NaN             NaN
# 5142               NaN                  NaN             NaN
# 5143               NaN                  NaN             NaN
#
#       B_avg_HEAD_landed  B_avg_KD  B_avg_LEG_att  B_avg_LEG_landed  \
# 0             11.200000  0.800000            7.6          5.400000
# 1             32.000000  0.000000           12.3         10.200000
# 2             23.258065  0.645161           14.0         12.193548
# 3             53.750000  0.500000            3.0          2.500000
# 4             45.000000  0.000000            2.0          2.000000
# ...                 ...       ...            ...               ...
# 5139          12.000000  2.000000            0.0          0.000000
# 5140                NaN       NaN            NaN               NaN
# 5141                NaN       NaN            NaN               NaN
# 5142                NaN       NaN            NaN               NaN
# 5143                NaN       NaN            NaN               NaN
#
#       B_avg_PASS  B_avg_REV  B_avg_SIG_STR_att  B_avg_SIG_STR_landed  \
# 0       0.400000   0.000000              65.40             22.600000
# 1       0.800000   0.000000             138.90             51.300000
# 2       0.935484   0.096774              97.00             46.774194
# 3       0.500000   0.250000             136.25             70.250000
# 4       0.000000   0.000000             203.50             61.500000
# ...          ...        ...                ...                   ...
# 5139    0.000000   0.000000              27.00             15.000000
# 5140         NaN        NaN                NaN                   NaN
# 5141         NaN        NaN                NaN                   NaN
# 5142         NaN        NaN                NaN                   NaN
# 5143         NaN        NaN                NaN                   NaN
#
#       B_avg_SIG_STR_pct  B_avg_SUB_ATT  B_avg_TD_att  B_avg_TD_landed  \
# 0              0.466000       0.400000       0.80000         0.200000
# 1              0.399000       0.700000       1.00000         0.500000
# 2              0.496129       0.354839       2.16129         0.677419
# 3              0.550000       0.250000       2.50000         1.250000
# 4              0.310000       0.000000       0.00000         0.000000
# ...                 ...            ...           ...              ...
# 5139           0.550000       0.000000       0.00000         0.000000
# 5140                NaN            NaN           NaN              NaN
# 5141                NaN            NaN           NaN              NaN
# 5142                NaN            NaN           NaN              NaN
# 5143                NaN            NaN           NaN              NaN
#
#       B_avg_TD_pct  B_avg_TOTAL_STR_att  B_avg_TOTAL_STR_landed  \
# 0         0.100000            66.400000               23.600000
# 1         0.225000           158.700000               69.600000
# 2         0.295484           103.709677               52.548387
# 3         0.287500           154.750000               86.750000
# 4         0.000000           204.000000               62.000000
# ...            ...                  ...                     ...
# 5139      0.000000            53.000000               38.000000
# 5140           NaN                  NaN                     NaN
# 5141           NaN                  NaN                     NaN
# 5142           NaN                  NaN                     NaN
# 5143           NaN                  NaN                     NaN
#
#       B_longest_win_streak  B_losses  B_avg_opp_BODY_att  \
# 0                      4.0       1.0            6.400000
# 1                      3.0       6.0           13.000000
# 2                      8.0       8.0           17.903226
# 3                      4.0       0.0           12.250000
# 4                      1.0       1.0           42.500000
# ...                    ...       ...                 ...
# 5139                   1.0       0.0            6.000000
# 5140                   0.0       0.0                 NaN
# 5141                   0.0       0.0                 NaN
# 5142                   0.0       0.0                 NaN
# 5143                   0.0       0.0                 NaN
#
#       B_avg_opp_BODY_landed  B_avg_opp_CLINCH_att  B_avg_opp_CLINCH_landed  \
# 0                  4.000000              1.000000                  0.60000
# 1                  9.300000             12.800000                  9.60000
# 2                 11.870968              8.419355                  5.83871
# 3                  6.000000              6.000000                  3.75000
# 4                 23.500000              0.500000                  0.50000
# ...                     ...                   ...                      ...
# 5139               3.000000             19.000000                 10.00000
# 5140                    NaN                   NaN                      NaN
# 5141                    NaN                   NaN                      NaN
# 5142                    NaN                   NaN                      NaN
# 5143                    NaN                   NaN                      NaN
#
#       B_avg_opp_DISTANCE_att  B_avg_opp_DISTANCE_landed  B_avg_opp_GROUND_att  \
# 0                  51.200000                  17.400000              0.600000
# 1                 101.700000                  32.000000              8.100000
# 2                  84.548387                  38.064516              1.741935
# 3                  94.250000                  26.750000              1.750000
# 4                 205.000000                  89.500000              0.000000
# ...                      ...                        ...                   ...
# 5139                7.000000                   0.000000              2.000000
# 5140                     NaN                        NaN                   NaN
# 5141                     NaN                        NaN                   NaN
# 5142                     NaN                        NaN                   NaN
# 5143                     NaN                        NaN                   NaN
#
#       B_avg_opp_GROUND_landed  B_avg_opp_HEAD_att  B_avg_opp_HEAD_landed  \
# 0                    0.200000           39.600000               9.400000
# 1                    6.900000           97.700000              30.800000
# 2                    0.935484           67.645161              25.483871
# 3                    1.250000           82.500000              21.500000
# 4                    0.000000          152.500000              56.500000
# ...                       ...                 ...                    ...
# 5139                 2.000000           19.000000               7.000000
# 5140                      NaN                 NaN                    NaN
# 5141                      NaN                 NaN                    NaN
# 5142                      NaN                 NaN                    NaN
# 5143                      NaN                 NaN                    NaN
#
#       B_avg_opp_KD  B_avg_opp_LEG_att  B_avg_opp_LEG_landed  B_avg_opp_PASS  \
# 0         0.200000            6.80000              4.800000        0.000000
# 1         0.100000           11.90000              8.400000        1.400000
# 2         0.225806            9.16129              7.483871        0.032258
# 3         0.250000            7.25000              4.250000        0.000000
# 4         0.000000           10.50000             10.000000        0.000000
# ...            ...                ...                   ...             ...
# 5139      0.000000            3.00000              2.000000        0.000000
# 5140           NaN                NaN                   NaN             NaN
# 5141           NaN                NaN                   NaN             NaN
# 5142           NaN                NaN                   NaN             NaN
# 5143           NaN                NaN                   NaN             NaN
#
#       B_avg_opp_REV  B_avg_opp_SIG_STR_att  B_avg_opp_SIG_STR_landed  \
# 0          0.000000              52.800000                  18.20000
# 1          0.000000             122.600000                  48.50000
# 2          0.032258              94.709677                  44.83871
# 3          0.000000             102.000000                  31.75000
# 4          0.000000             205.500000                  90.00000
# ...             ...                    ...                       ...
# 5139       0.000000              28.000000                  12.00000
# 5140            NaN                    NaN                       NaN
# 5141            NaN                    NaN                       NaN
# 5142            NaN                    NaN                       NaN
# 5143            NaN                    NaN                       NaN
#
#       B_avg_opp_SIG_STR_pct  B_avg_opp_SUB_ATT  B_avg_opp_TD_att  \
# 0                  0.236000           0.000000          1.000000
# 1                  0.408000           0.700000          2.300000
# 2                  0.453226           0.096774          2.096774
# 3                  0.337500           0.000000          4.500000
# 4                  0.430000           0.000000          0.500000
# ...                     ...                ...               ...
# 5139               0.420000           0.000000          0.000000
# 5140                    NaN                NaN               NaN
# 5141                    NaN                NaN               NaN
# 5142                    NaN                NaN               NaN
# 5143                    NaN                NaN               NaN
#
#       B_avg_opp_TD_landed  B_avg_opp_TD_pct  B_avg_opp_TOTAL_STR_att  \
# 0                0.400000          0.100000                53.800000
# 1                0.900000          0.231000               151.500000
# 2                0.225806          0.063548               100.387097
# 3                0.750000          0.097500               104.750000
# 4                0.000000          0.000000               205.500000
# ...                   ...               ...                      ...
# 5139             0.000000          0.000000                29.000000
# 5140                  NaN               NaN                      NaN
# 5141                  NaN               NaN                      NaN
# 5142                  NaN               NaN                      NaN
# 5143                  NaN               NaN                      NaN
#
#       B_avg_opp_TOTAL_STR_landed  B_total_rounds_fought  \
# 0                      19.200000                    9.0
# 1                      75.400000                   29.0
# 2                      49.774194                   68.0
# 3                      34.250000                    9.0
# 4                      90.000000                    8.0
# ...                          ...                    ...
# 5139                   13.000000                    1.0
# 5140                         NaN                    0.0
# 5141                         NaN                    0.0
# 5142                         NaN                    0.0
# 5143                         NaN                    0.0
#
#       B_total_time_fought(seconds)  B_total_title_bouts  \
# 0                       419.400000                  0.0
# 1                       849.000000                  0.0
# 2                       581.870968                  1.0
# 3                       652.000000                  0.0
# 4                      1200.000000                  0.0
# ...                            ...                  ...
# 5139                    260.000000                  0.0
# 5140                           NaN                  0.0
# 5141                           NaN                  0.0
# 5142                           NaN                  0.0
# 5143                           NaN                  0.0
#
#       B_win_by_Decision_Majority  B_win_by_Decision_Split  \
# 0                            0.0                      1.0
# 1                            0.0                      2.0
# 2                            0.0                      0.0
# 3                            0.0                      0.0
# 4                            0.0                      0.0
# ...                          ...                      ...
# 5139                         0.0                      0.0
# 5140                         0.0                      0.0
# 5141                         0.0                      0.0
# 5142                         0.0                      0.0
# 5143                         0.0                      0.0
#
#       B_win_by_Decision_Unanimous  B_win_by_KO/TKO  B_win_by_Submission  \
# 0                             0.0              2.0                  1.0
# 1                             1.0              0.0                  0.0
# 2                             7.0             10.0                  6.0
# 3                             2.0              2.0                  0.0
# 4                             1.0              0.0                  0.0
# ...                           ...              ...                  ...
# 5139                          0.0              1.0                  0.0
# 5140                          0.0              0.0                  0.0
# 5141                          0.0              0.0                  0.0
# 5142                          0.0              0.0                  0.0
# 5143                          0.0              0.0                  0.0
#
#       B_win_by_TKO_Doctor_Stoppage  B_wins  B_Stance  B_Height_cms  \
# 0                              0.0     4.0  Orthodox        167.64
# 1                              1.0     4.0  Orthodox        167.64
# 2                              0.0    23.0  Orthodox        185.42
# 3                              0.0     4.0    Switch        170.18
# 4                              0.0     1.0  Southpaw        180.34
# ...                            ...     ...       ...           ...
# 5139                           0.0     1.0  Orthodox        193.04
# 5140                           0.0     0.0  Orthodox        187.96
# 5141                           0.0     0.0  Orthodox        185.42
# 5142                           0.0     0.0  Orthodox        195.58
# 5143                           0.0     0.0  Orthodox        182.88
#
#       B_Reach_cms  B_Weight_lbs  R_current_lose_streak  R_current_win_streak  \
# 0          170.18         135.0                    0.0                   4.0
# 1          167.64         125.0                    0.0                   2.0
# 2          185.42         155.0                    0.0                  11.0
# 3          170.18         135.0                    1.0                   0.0
# 4          185.42         250.0                    1.0                   0.0
# ...           ...           ...                    ...                   ...
# 5139          NaN         275.0                    0.0                   1.0
# 5140          NaN         225.0                    0.0                   0.0
# 5141          NaN         196.0                    0.0                   0.0
# 5142          NaN         250.0                    0.0                   0.0
# 5143          NaN         430.0                    0.0                   0.0
#
#       R_draw  R_avg_BODY_att  R_avg_BODY_landed  R_avg_CLINCH_att  \
# 0        0.0       21.900000          16.400000         17.000000
# 1        0.0       12.000000           7.714286          9.285714
# 2        0.0       13.866667           8.666667          2.866667
# 3        0.0       18.250000          10.250000          5.875000
# 4        0.0        7.750000           6.750000         11.000000
# ...      ...             ...                ...               ...
# 5139     0.0        0.000000           0.000000          0.000000
# 5140     0.0             NaN                NaN               NaN
# 5141     0.0             NaN                NaN               NaN
# 5142     0.0             NaN                NaN               NaN
# 5143     0.0             NaN                NaN               NaN
#
#       R_avg_CLINCH_landed  R_avg_DISTANCE_att  R_avg_DISTANCE_landed  \
# 0               11.000000           75.000000              26.500000
# 1                6.857143           88.142857              36.142857
# 2                1.733333          116.133333              49.466667
# 3                4.125000          104.875000              41.000000
# 4                7.250000           50.750000              24.750000
# ...                   ...                 ...                    ...
# 5139             0.000000            3.000000               1.000000
# 5140                  NaN                 NaN                    NaN
# 5141                  NaN                 NaN                    NaN
# 5142                  NaN                 NaN                    NaN
# 5143                  NaN                 NaN                    NaN
#
#       R_avg_GROUND_att  R_avg_GROUND_landed  R_avg_HEAD_att  \
# 0             9.400000             6.500000       74.200000
# 1            18.428571            16.428571       84.571429
# 2             5.333333             4.266667       96.733333
# 3             1.000000             0.625000       80.500000
# 4             0.500000             0.500000       50.750000
# ...                ...                  ...             ...
# 5139          2.000000             2.000000        5.000000
# 5140               NaN                  NaN             NaN
# 5141               NaN                  NaN             NaN
# 5142               NaN                  NaN             NaN
# 5143               NaN                  NaN             NaN
#
#       R_avg_HEAD_landed  R_avg_KD  R_avg_LEG_att  R_avg_LEG_landed  \
# 0                 23.90     0.400       5.300000          3.700000
# 1                 37.00     0.000      19.285714         14.714286
# 2                 35.60     0.200      13.733333         11.200000
# 3                 24.00     0.375      13.000000         11.500000
# 4                 22.75     0.500       3.750000          3.000000
# ...                 ...       ...            ...               ...
# 5139               3.00     0.000       0.000000          0.000000
# 5140                NaN       NaN            NaN               NaN
# 5141                NaN       NaN            NaN               NaN
# 5142                NaN       NaN            NaN               NaN
# 5143                NaN       NaN            NaN               NaN
#
#       R_avg_PASS  R_avg_REV  R_avg_SIG_STR_att  R_avg_SIG_STR_landed  \
# 0       1.200000   0.000000         101.400000             44.000000
# 1       1.714286   0.142857         115.857143             59.428571
# 2       0.333333   0.133333         124.333333             55.466667
# 3       0.125000   0.000000         111.750000             45.750000
# 4       0.250000   0.000000          62.250000             32.500000
# ...          ...        ...                ...                   ...
# 5139    0.000000   0.000000           5.000000              3.000000
# 5140         NaN        NaN                NaN                   NaN
# 5141         NaN        NaN                NaN                   NaN
# 5142         NaN        NaN                NaN                   NaN
# 5143         NaN        NaN                NaN                   NaN
#
#       R_avg_SIG_STR_pct  R_avg_SUB_ATT  R_avg_TD_att  R_avg_TD_landed  \
# 0              0.466000       0.100000      5.300000         1.900000
# 1              0.575714       0.428571      5.142857         2.428571
# 2              0.430000       1.000000      0.933333         0.400000
# 3              0.366250       0.000000      2.250000         0.625000
# 4              0.545000       0.000000      0.500000         0.000000
# ...                 ...            ...           ...              ...
# 5139           0.600000       0.000000      0.000000         0.000000
# 5140                NaN            NaN           NaN              NaN
# 5141                NaN            NaN           NaN              NaN
# 5142                NaN            NaN           NaN              NaN
# 5143                NaN            NaN           NaN              NaN
#
#       R_avg_TD_pct  R_avg_TOTAL_STR_att  R_avg_TOTAL_STR_landed  \
# 0         0.458000           129.900000               69.100000
# 1         0.601429           161.571429              102.857143
# 2         0.277333           133.000000               63.400000
# 3         0.103750           117.375000               50.750000
# 4         0.000000            63.500000               32.750000
# ...            ...                  ...                     ...
# 5139      0.000000             5.000000                3.000000
# 5140           NaN                  NaN                     NaN
# 5141           NaN                  NaN                     NaN
# 5142           NaN                  NaN                     NaN
# 5143           NaN                  NaN                     NaN
#
#       R_longest_win_streak  R_losses  R_avg_opp_BODY_att  \
# 0                      4.0       2.0           13.300000
# 1                      2.0       2.0           24.571429
# 2                     11.0       1.0           14.466667
# 3                      5.0       2.0           20.250000
# 4                      3.0       1.0            6.250000
# ...                    ...       ...                 ...
# 5139                   1.0       0.0            0.000000
# 5140                   0.0       0.0                 NaN
# 5141                   0.0       0.0                 NaN
# 5142                   0.0       0.0                 NaN
# 5143                   0.0       0.0                 NaN
#
#       R_avg_opp_BODY_landed  R_avg_opp_CLINCH_att  R_avg_opp_CLINCH_landed  \
# 0                  8.800000              7.500000                 5.100000
# 1                 14.142857             10.571429                 7.857143
# 2                  8.133333              2.800000                 0.733333
# 3                 13.375000              6.875000                 5.625000
# 4                  4.750000              4.500000                 3.500000
# ...                     ...                   ...                      ...
# 5139               0.000000              0.000000                 0.000000
# 5140                    NaN                   NaN                      NaN
# 5141                    NaN                   NaN                      NaN
# 5142                    NaN                   NaN                      NaN
# 5143                    NaN                   NaN                      NaN
#
#       R_avg_opp_DISTANCE_att  R_avg_opp_DISTANCE_landed  R_avg_opp_GROUND_att  \
# 0                  90.500000                  26.800000              0.800000
# 1                  98.571429                  32.571429              6.428571
# 2                  91.066667                  32.200000              4.866667
# 3                 103.125000                  38.500000              0.875000
# 4                  42.750000                  16.250000              7.750000
# ...                      ...                        ...                   ...
# 5139                1.000000                   0.000000              0.000000
# 5140                     NaN                        NaN                   NaN
# 5141                     NaN                        NaN                   NaN
# 5142                     NaN                        NaN                   NaN
# 5143                     NaN                        NaN                   NaN
#
#       R_avg_opp_GROUND_landed  R_avg_opp_HEAD_att  R_avg_opp_HEAD_landed  \
# 0                    0.300000           76.100000              17.300000
# 1                    4.285714           61.857143              12.428571
# 2                    2.800000           78.266667              23.200000
# 3                    0.750000           77.375000              20.375000
# 4                    2.750000           43.250000              14.000000
# ...                       ...                 ...                    ...
# 5139                 0.000000            1.000000               0.000000
# 5140                      NaN                 NaN                    NaN
# 5141                      NaN                 NaN                    NaN
# 5142                      NaN                 NaN                    NaN
# 5143                      NaN                 NaN                    NaN
#
#       R_avg_opp_KD  R_avg_opp_LEG_att  R_avg_opp_LEG_landed  R_avg_opp_PASS  \
# 0         0.100000           9.400000              6.100000        0.000000
# 1         0.000000          29.142857             18.142857        1.142857
# 2         0.266667           6.000000              4.400000        0.333333
# 3         0.125000          13.250000             11.125000        0.000000
# 4         0.250000           5.500000              3.750000        0.750000
# ...            ...                ...                   ...             ...
# 5139      0.000000           0.000000              0.000000        0.000000
# 5140           NaN                NaN                   NaN             NaN
# 5141           NaN                NaN                   NaN             NaN
# 5142           NaN                NaN                   NaN             NaN
# 5143           NaN                NaN                   NaN             NaN
#
#       R_avg_opp_REV  R_avg_opp_SIG_STR_att  R_avg_opp_SIG_STR_landed  \
# 0          0.000000              98.800000                 32.200000
# 1          0.000000             115.571429                 44.714286
# 2          0.133333              98.733333                 35.733333
# 3          0.000000             110.875000                 44.875000
# 4          0.000000              55.000000                 22.500000
# ...             ...                    ...                       ...
# 5139       0.000000               1.000000                  0.000000
# 5140            NaN                    NaN                       NaN
# 5141            NaN                    NaN                       NaN
# 5142            NaN                    NaN                       NaN
# 5143            NaN                    NaN                       NaN
#
#       R_avg_opp_SIG_STR_pct  R_avg_opp_SUB_ATT  R_avg_opp_TD_att  \
# 0                  0.336000           0.000000          0.900000
# 1                  0.437143           0.285714          3.285714
# 2                  0.340000           0.066667          2.866667
# 3                  0.446250           0.000000          2.375000
# 4                  0.397500           0.000000          1.000000
# ...                     ...                ...               ...
# 5139               0.000000           0.000000          1.000000
# 5140                    NaN                NaN               NaN
# 5141                    NaN                NaN               NaN
# 5142                    NaN                NaN               NaN
# 5143                    NaN                NaN               NaN
#
#       R_avg_opp_TD_landed  R_avg_opp_TD_pct  R_avg_opp_TOTAL_STR_att  \
# 0                0.100000          0.050000               110.500000
# 1                0.857143          0.147143               158.142857
# 2                0.666667          0.131333               102.133333
# 3                0.000000          0.000000               115.125000
# 4                0.000000          0.000000                60.500000
# ...                   ...               ...                      ...
# 5139             0.000000          0.000000                 1.000000
# 5140                  NaN               NaN                      NaN
# 5141                  NaN               NaN                      NaN
# 5142                  NaN               NaN                      NaN
# 5143                  NaN               NaN                      NaN
#
#       R_avg_opp_TOTAL_STR_landed  R_total_rounds_fought  \
# 0                      43.300000                   27.0
# 1                      82.285714                   25.0
# 2                      38.600000                   33.0
# 3                      48.875000                   20.0
# 4                      27.750000                    7.0
# ...                          ...                    ...
# 5139                    0.000000                    1.0
# 5140                         NaN                    0.0
# 5141                         NaN                    0.0
# 5142                         NaN                    0.0
# 5143                         NaN                    0.0
#
#       R_total_time_fought(seconds)  R_total_title_bouts  \
# 0                           742.60                  3.0
# 1                          1062.00                  2.0
# 2                           604.40                  2.0
# 3                           690.25                  0.0
# 4                           440.75                  0.0
# ...                            ...                  ...
# 5139                         26.00                  0.0
# 5140                           NaN                  0.0
# 5141                           NaN                  0.0
# 5142                           NaN                  0.0
# 5143                           NaN                  0.0
#
#       R_win_by_Decision_Majority  R_win_by_Decision_Split  \
# 0                            0.0                      2.0
# 1                            0.0                      1.0
# 2                            0.0                      1.0
# 3                            0.0                      1.0
# 4                            0.0                      0.0
# ...                          ...                      ...
# 5139                         0.0                      0.0
# 5140                         0.0                      0.0
# 5141                         0.0                      0.0
# 5142                         0.0                      0.0
# 5143                         0.0                      0.0
#
#       R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                             4.0              2.0                  0.0
# 1                             2.0              0.0                  2.0
# 2                             3.0              3.0                  6.0
# 3                             4.0              1.0                  0.0
# 4                             1.0              2.0                  0.0
# ...                           ...              ...                  ...
# 5139                          0.0              1.0                  0.0
# 5140                          0.0              0.0                  0.0
# 5141                          0.0              0.0                  0.0
# 5142                          0.0              0.0                  0.0
# 5143                          0.0              0.0                  0.0
#
#       R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  \
# 0                              0.0     8.0  Orthodox        162.56
# 1                              0.0     5.0  Southpaw        165.10
# 2                              1.0    14.0  Orthodox        180.34
# 3                              0.0     6.0  Orthodox        162.56
# 4                              0.0     3.0  Southpaw        187.96
# ...                            ...     ...       ...           ...
# 5139                           0.0     1.0  Orthodox        195.58
# 5140                           0.0     0.0  Orthodox        185.42
# 5141                           0.0     0.0  Southpaw        185.42
# 5142                           0.0     0.0  Orthodox        193.04
# 5143                           0.0     0.0  Orthodox        195.58
#
#       R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0          162.56         135.0   31.0   32.0
# 1          167.64         125.0   32.0   31.0
# 2          193.04         155.0   36.0   35.0
# 3          172.72         135.0   26.0   29.0
# 4          190.50         264.0   32.0   26.0
# ...           ...           ...    ...    ...
# 5139          NaN         216.0    NaN   34.0
# 5140       182.88         205.0   30.0   29.0
# 5141          NaN         175.0   30.0   26.0
# 5142          NaN         275.0    NaN    NaN
# 5143          NaN         216.0   24.0   34.0
#
# [5144 rows x 145 columns]

# %%
df.T
# Out:
#                                                 0                       1     \
# R_fighter                               Henry Cejudo    Valentina Shevchenko
# B_fighter                              Marlon Moraes             Jessica Eye
# Referee                                 Marc Goddard         Robert Madrigal
# date                                      2019-06-08              2019-06-08
# location                      Chicago, Illinois, USA  Chicago, Illinois, USA
# Winner                                           Red                     Red
# title_bout                                      True                    True
# weight_class                            Bantamweight       Women's Flyweight
# no_of_rounds                                       5                       5
# B_current_lose_streak                              0                       0
# B_current_win_streak                               4                       3
# B_draw                                             0                       0
# B_avg_BODY_att                                   9.2                    14.6
# B_avg_BODY_landed                                  6                     9.1
# B_avg_CLINCH_att                                 0.2                    11.8
# B_avg_CLINCH_landed                                0                     7.3
# B_avg_DISTANCE_att                              62.6                   124.7
# B_avg_DISTANCE_landed                           20.6                    42.1
# B_avg_GROUND_att                                 2.6                     2.4
# B_avg_GROUND_landed                                2                     1.9
# B_avg_HEAD_att                                  48.6                     112
# B_avg_HEAD_landed                               11.2                      32
# B_avg_KD                                         0.8                       0
# B_avg_LEG_att                                    7.6                    12.3
# B_avg_LEG_landed                                 5.4                    10.2
# B_avg_PASS                                       0.4                     0.8
# B_avg_REV                                          0                       0
# B_avg_SIG_STR_att                               65.4                   138.9
# B_avg_SIG_STR_landed                            22.6                    51.3
# B_avg_SIG_STR_pct                              0.466                   0.399
# B_avg_SUB_ATT                                    0.4                     0.7
# B_avg_TD_att                                     0.8                       1
# B_avg_TD_landed                                  0.2                     0.5
# B_avg_TD_pct                                     0.1                   0.225
# B_avg_TOTAL_STR_att                             66.4                   158.7
# B_avg_TOTAL_STR_landed                          23.6                    69.6
# B_longest_win_streak                               4                       3
# B_losses                                           1                       6
# B_avg_opp_BODY_att                               6.4                      13
# B_avg_opp_BODY_landed                              4                     9.3
# B_avg_opp_CLINCH_att                               1                    12.8
# B_avg_opp_CLINCH_landed                          0.6                     9.6
# B_avg_opp_DISTANCE_att                          51.2                   101.7
# B_avg_opp_DISTANCE_landed                       17.4                      32
# B_avg_opp_GROUND_att                             0.6                     8.1
# B_avg_opp_GROUND_landed                          0.2                     6.9
# B_avg_opp_HEAD_att                              39.6                    97.7
# B_avg_opp_HEAD_landed                            9.4                    30.8
# B_avg_opp_KD                                     0.2                     0.1
# B_avg_opp_LEG_att                                6.8                    11.9
# B_avg_opp_LEG_landed                             4.8                     8.4
# B_avg_opp_PASS                                     0                     1.4
# B_avg_opp_REV                                      0                       0
# B_avg_opp_SIG_STR_att                           52.8                   122.6
# B_avg_opp_SIG_STR_landed                        18.2                    48.5
# B_avg_opp_SIG_STR_pct                          0.236                   0.408
# B_avg_opp_SUB_ATT                                  0                     0.7
# B_avg_opp_TD_att                                   1                     2.3
# B_avg_opp_TD_landed                              0.4                     0.9
# B_avg_opp_TD_pct                                 0.1                   0.231
# B_avg_opp_TOTAL_STR_att                         53.8                   151.5
# B_avg_opp_TOTAL_STR_landed                      19.2                    75.4
# B_total_rounds_fought                              9                      29
# B_total_time_fought(seconds)                   419.4                     849
# B_total_title_bouts                                0                       0
# B_win_by_Decision_Majority                         0                       0
# B_win_by_Decision_Split                            1                       2
# B_win_by_Decision_Unanimous                        0                       1
# B_win_by_KO/TKO                                    2                       0
# B_win_by_Submission                                1                       0
# B_win_by_TKO_Doctor_Stoppage                       0                       1
# B_wins                                             4                       4
# B_Stance                                    Orthodox                Orthodox
# B_Height_cms                                  167.64                  167.64
# B_Reach_cms                                   170.18                  167.64
# B_Weight_lbs                                     135                     125
# R_current_lose_streak                              0                       0
# R_current_win_streak                               4                       2
# R_draw                                             0                       0
# R_avg_BODY_att                                  21.9                      12
# R_avg_BODY_landed                               16.4                 7.71429
# R_avg_CLINCH_att                                  17                 9.28571
# R_avg_CLINCH_landed                               11                 6.85714
# R_avg_DISTANCE_att                                75                 88.1429
# R_avg_DISTANCE_landed                           26.5                 36.1429
# R_avg_GROUND_att                                 9.4                 18.4286
# R_avg_GROUND_landed                              6.5                 16.4286
# R_avg_HEAD_att                                  74.2                 84.5714
# R_avg_HEAD_landed                               23.9                      37
# R_avg_KD                                         0.4                       0
# R_avg_LEG_att                                    5.3                 19.2857
# R_avg_LEG_landed                                 3.7                 14.7143
# R_avg_PASS                                       1.2                 1.71429
# R_avg_REV                                          0                0.142857
# R_avg_SIG_STR_att                              101.4                 115.857
# R_avg_SIG_STR_landed                              44                 59.4286
# R_avg_SIG_STR_pct                              0.466                0.575714
# R_avg_SUB_ATT                                    0.1                0.428571
# R_avg_TD_att                                     5.3                 5.14286
# R_avg_TD_landed                                  1.9                 2.42857
# R_avg_TD_pct                                   0.458                0.601429
# R_avg_TOTAL_STR_att                            129.9                 161.571
# R_avg_TOTAL_STR_landed                          69.1                 102.857
# R_longest_win_streak                               4                       2
# R_losses                                           2                       2
# R_avg_opp_BODY_att                              13.3                 24.5714
# R_avg_opp_BODY_landed                            8.8                 14.1429
# R_avg_opp_CLINCH_att                             7.5                 10.5714
# R_avg_opp_CLINCH_landed                          5.1                 7.85714
# R_avg_opp_DISTANCE_att                          90.5                 98.5714
# R_avg_opp_DISTANCE_landed                       26.8                 32.5714
# R_avg_opp_GROUND_att                             0.8                 6.42857
# R_avg_opp_GROUND_landed                          0.3                 4.28571
# R_avg_opp_HEAD_att                              76.1                 61.8571
# R_avg_opp_HEAD_landed                           17.3                 12.4286
# R_avg_opp_KD                                     0.1                       0
# R_avg_opp_LEG_att                                9.4                 29.1429
# R_avg_opp_LEG_landed                             6.1                 18.1429
# R_avg_opp_PASS                                     0                 1.14286
# R_avg_opp_REV                                      0                       0
# R_avg_opp_SIG_STR_att                           98.8                 115.571
# R_avg_opp_SIG_STR_landed                        32.2                 44.7143
# R_avg_opp_SIG_STR_pct                          0.336                0.437143
# R_avg_opp_SUB_ATT                                  0                0.285714
# R_avg_opp_TD_att                                 0.9                 3.28571
# R_avg_opp_TD_landed                              0.1                0.857143
# R_avg_opp_TD_pct                                0.05                0.147143
# R_avg_opp_TOTAL_STR_att                        110.5                 158.143
# R_avg_opp_TOTAL_STR_landed                      43.3                 82.2857
# R_total_rounds_fought                             27                      25
# R_total_time_fought(seconds)                   742.6                    1062
# R_total_title_bouts                                3                       2
# R_win_by_Decision_Majority                         0                       0
# R_win_by_Decision_Split                            2                       1
# R_win_by_Decision_Unanimous                        4                       2
# R_win_by_KO/TKO                                    2                       0
# R_win_by_Submission                                0                       2
# R_win_by_TKO_Doctor_Stoppage                       0                       0
# R_wins                                             8                       5
# R_Stance                                    Orthodox                Southpaw
# R_Height_cms                                  162.56                   165.1
# R_Reach_cms                                   162.56                  167.64
# R_Weight_lbs                                     135                     125
# B_age                                             31                      32
# R_age                                             32                      31
#
#                                                 2                       3     \
# R_fighter                              Tony Ferguson           Jimmie Rivera
# B_fighter                             Donald Cerrone                Petr Yan
# Referee                              Dan Miragliotta         Kevin MacDonald
# date                                      2019-06-08              2019-06-08
# location                      Chicago, Illinois, USA  Chicago, Illinois, USA
# Winner                                           Red                    Blue
# title_bout                                     False                   False
# weight_class                             Lightweight            Bantamweight
# no_of_rounds                                       3                       3
# B_current_lose_streak                              0                       0
# B_current_win_streak                               3                       4
# B_draw                                             0                       0
# B_avg_BODY_att                               15.3548                      17
# B_avg_BODY_landed                            11.3226                      14
# B_avg_CLINCH_att                             6.74194                   13.75
# B_avg_CLINCH_landed                           4.3871                      11
# B_avg_DISTANCE_att                           84.7419                   109.5
# B_avg_DISTANCE_landed                        38.5806                   48.75
# B_avg_GROUND_att                             5.51613                      13
# B_avg_GROUND_landed                          3.80645                    10.5
# B_avg_HEAD_att                               67.6452                  116.25
# B_avg_HEAD_landed                            23.2581                   53.75
# B_avg_KD                                    0.645161                     0.5
# B_avg_LEG_att                                     14                       3
# B_avg_LEG_landed                             12.1935                     2.5
# B_avg_PASS                                  0.935484                     0.5
# B_avg_REV                                  0.0967742                    0.25
# B_avg_SIG_STR_att                                 97                  136.25
# B_avg_SIG_STR_landed                         46.7742                   70.25
# B_avg_SIG_STR_pct                           0.496129                    0.55
# B_avg_SUB_ATT                               0.354839                    0.25
# B_avg_TD_att                                 2.16129                     2.5
# B_avg_TD_landed                             0.677419                    1.25
# B_avg_TD_pct                                0.295484                  0.2875
# B_avg_TOTAL_STR_att                           103.71                  154.75
# B_avg_TOTAL_STR_landed                       52.5484                   86.75
# B_longest_win_streak                               8                       4
# B_losses                                           8                       0
# B_avg_opp_BODY_att                           17.9032                   12.25
# B_avg_opp_BODY_landed                         11.871                       6
# B_avg_opp_CLINCH_att                         8.41935                       6
# B_avg_opp_CLINCH_landed                      5.83871                    3.75
# B_avg_opp_DISTANCE_att                       84.5484                   94.25
# B_avg_opp_DISTANCE_landed                    38.0645                   26.75
# B_avg_opp_GROUND_att                         1.74194                    1.75
# B_avg_opp_GROUND_landed                     0.935484                    1.25
# B_avg_opp_HEAD_att                           67.6452                    82.5
# B_avg_opp_HEAD_landed                        25.4839                    21.5
# B_avg_opp_KD                                0.225806                    0.25
# B_avg_opp_LEG_att                            9.16129                    7.25
# B_avg_opp_LEG_landed                         7.48387                    4.25
# B_avg_opp_PASS                             0.0322581                       0
# B_avg_opp_REV                              0.0322581                       0
# B_avg_opp_SIG_STR_att                        94.7097                     102
# B_avg_opp_SIG_STR_landed                     44.8387                   31.75
# B_avg_opp_SIG_STR_pct                       0.453226                  0.3375
# B_avg_opp_SUB_ATT                          0.0967742                       0
# B_avg_opp_TD_att                             2.09677                     4.5
# B_avg_opp_TD_landed                         0.225806                    0.75
# B_avg_opp_TD_pct                           0.0635484                  0.0975
# B_avg_opp_TOTAL_STR_att                      100.387                  104.75
# B_avg_opp_TOTAL_STR_landed                   49.7742                   34.25
# B_total_rounds_fought                             68                       9
# B_total_time_fought(seconds)                 581.871                     652
# B_total_title_bouts                                1                       0
# B_win_by_Decision_Majority                         0                       0
# B_win_by_Decision_Split                            0                       0
# B_win_by_Decision_Unanimous                        7                       2
# B_win_by_KO/TKO                                   10                       2
# B_win_by_Submission                                6                       0
# B_win_by_TKO_Doctor_Stoppage                       0                       0
# B_wins                                            23                       4
# B_Stance                                    Orthodox                  Switch
# B_Height_cms                                  185.42                  170.18
# B_Reach_cms                                   185.42                  170.18
# B_Weight_lbs                                     155                     135
# R_current_lose_streak                              0                       1
# R_current_win_streak                              11                       0
# R_draw                                             0                       0
# R_avg_BODY_att                               13.8667                   18.25
# R_avg_BODY_landed                            8.66667                   10.25
# R_avg_CLINCH_att                             2.86667                   5.875
# R_avg_CLINCH_landed                          1.73333                   4.125
# R_avg_DISTANCE_att                           116.133                 104.875
# R_avg_DISTANCE_landed                        49.4667                      41
# R_avg_GROUND_att                             5.33333                       1
# R_avg_GROUND_landed                          4.26667                   0.625
# R_avg_HEAD_att                               96.7333                    80.5
# R_avg_HEAD_landed                               35.6                      24
# R_avg_KD                                         0.2                   0.375
# R_avg_LEG_att                                13.7333                      13
# R_avg_LEG_landed                                11.2                    11.5
# R_avg_PASS                                  0.333333                   0.125
# R_avg_REV                                   0.133333                       0
# R_avg_SIG_STR_att                            124.333                  111.75
# R_avg_SIG_STR_landed                         55.4667                   45.75
# R_avg_SIG_STR_pct                               0.43                 0.36625
# R_avg_SUB_ATT                                      1                       0
# R_avg_TD_att                                0.933333                    2.25
# R_avg_TD_landed                                  0.4                   0.625
# R_avg_TD_pct                                0.277333                 0.10375
# R_avg_TOTAL_STR_att                              133                 117.375
# R_avg_TOTAL_STR_landed                          63.4                   50.75
# R_longest_win_streak                              11                       5
# R_losses                                           1                       2
# R_avg_opp_BODY_att                           14.4667                   20.25
# R_avg_opp_BODY_landed                        8.13333                  13.375
# R_avg_opp_CLINCH_att                             2.8                   6.875
# R_avg_opp_CLINCH_landed                     0.733333                   5.625
# R_avg_opp_DISTANCE_att                       91.0667                 103.125
# R_avg_opp_DISTANCE_landed                       32.2                    38.5
# R_avg_opp_GROUND_att                         4.86667                   0.875
# R_avg_opp_GROUND_landed                          2.8                    0.75
# R_avg_opp_HEAD_att                           78.2667                  77.375
# R_avg_opp_HEAD_landed                           23.2                  20.375
# R_avg_opp_KD                                0.266667                   0.125
# R_avg_opp_LEG_att                                  6                   13.25
# R_avg_opp_LEG_landed                             4.4                  11.125
# R_avg_opp_PASS                              0.333333                       0
# R_avg_opp_REV                               0.133333                       0
# R_avg_opp_SIG_STR_att                        98.7333                 110.875
# R_avg_opp_SIG_STR_landed                     35.7333                  44.875
# R_avg_opp_SIG_STR_pct                           0.34                 0.44625
# R_avg_opp_SUB_ATT                          0.0666667                       0
# R_avg_opp_TD_att                             2.86667                   2.375
# R_avg_opp_TD_landed                         0.666667                       0
# R_avg_opp_TD_pct                            0.131333                       0
# R_avg_opp_TOTAL_STR_att                      102.133                 115.125
# R_avg_opp_TOTAL_STR_landed                      38.6                  48.875
# R_total_rounds_fought                             33                      20
# R_total_time_fought(seconds)                   604.4                  690.25
# R_total_title_bouts                                2                       0
# R_win_by_Decision_Majority                         0                       0
# R_win_by_Decision_Split                            1                       1
# R_win_by_Decision_Unanimous                        3                       4
# R_win_by_KO/TKO                                    3                       1
# R_win_by_Submission                                6                       0
# R_win_by_TKO_Doctor_Stoppage                       1                       0
# R_wins                                            14                       6
# R_Stance                                    Orthodox                Orthodox
# R_Height_cms                                  180.34                  162.56
# R_Reach_cms                                   193.04                  172.72
# R_Weight_lbs                                     155                     135
# B_age                                             36                      26
# R_age                                             35                      29
#
#                                                 4                       5     \
# R_fighter                                Tai Tuivasa          Tatiana Suarez
# B_fighter                              Blagoy Ivanov           Nina Ansaroff
# Referee                              Dan Miragliotta         Robert Madrigal
# date                                      2019-06-08              2019-06-08
# location                      Chicago, Illinois, USA  Chicago, Illinois, USA
# Winner                                          Blue                     Red
# title_bout                                     False                   False
# weight_class                             Heavyweight     Women's Strawweight
# no_of_rounds                                       3                       3
# B_current_lose_streak                              0                       0
# B_current_win_streak                               1                       4
# B_draw                                             0                       0
# B_avg_BODY_att                                    17                    19.5
# B_avg_BODY_landed                               14.5                 12.3333
# B_avg_CLINCH_att                                 2.5                 11.8333
# B_avg_CLINCH_landed                                2                 7.16667
# B_avg_DISTANCE_att                               201                 142.333
# B_avg_DISTANCE_landed                           59.5                 63.8333
# B_avg_GROUND_att                                   0                       6
# B_avg_GROUND_landed                                0                 4.16667
# B_avg_HEAD_att                                 184.5                 117.833
# B_avg_HEAD_landed                                 45                 42.6667
# B_avg_KD                                           0                       0
# B_avg_LEG_att                                      2                 22.8333
# B_avg_LEG_landed                                   2                 20.1667
# B_avg_PASS                                         0                 1.33333
# B_avg_REV                                          0                0.166667
# B_avg_SIG_STR_att                              203.5                 160.167
# B_avg_SIG_STR_landed                            61.5                 75.1667
# B_avg_SIG_STR_pct                               0.31                    0.47
# B_avg_SUB_ATT                                      0                0.666667
# B_avg_TD_att                                       0                0.833333
# B_avg_TD_landed                                    0                0.333333
# B_avg_TD_pct                                       0                    0.25
# B_avg_TOTAL_STR_att                              204                   183.5
# B_avg_TOTAL_STR_landed                            62                 95.6667
# B_longest_win_streak                               1                       4
# B_losses                                           1                       2
# B_avg_opp_BODY_att                              42.5                      12
# B_avg_opp_BODY_landed                           23.5                 7.33333
# B_avg_opp_CLINCH_att                             0.5                 9.66667
# B_avg_opp_CLINCH_landed                          0.5                       7
# B_avg_opp_DISTANCE_att                           205                 95.1667
# B_avg_opp_DISTANCE_landed                       89.5                 38.3333
# B_avg_opp_GROUND_att                               0                 5.16667
# B_avg_opp_GROUND_landed                            0                     3.5
# B_avg_opp_HEAD_att                             152.5                 86.6667
# B_avg_opp_HEAD_landed                           56.5                 33.1667
# B_avg_opp_KD                                       0                       0
# B_avg_opp_LEG_att                               10.5                 11.3333
# B_avg_opp_LEG_landed                              10                 8.33333
# B_avg_opp_PASS                                     0                     1.5
# B_avg_opp_REV                                      0                0.166667
# B_avg_opp_SIG_STR_att                          205.5                     110
# B_avg_opp_SIG_STR_landed                          90                 48.8333
# B_avg_opp_SIG_STR_pct                           0.43                0.426667
# B_avg_opp_SUB_ATT                                  0                       0
# B_avg_opp_TD_att                                 0.5                       6
# B_avg_opp_TD_landed                                0                 1.16667
# B_avg_opp_TD_pct                                   0                    0.14
# B_avg_opp_TOTAL_STR_att                        205.5                   131.5
# B_avg_opp_TOTAL_STR_landed                        90                 68.6667
# B_total_rounds_fought                              8                      18
# B_total_time_fought(seconds)                    1200                   886.5
# B_total_title_bouts                                0                       0
# B_win_by_Decision_Majority                         0                       0
# B_win_by_Decision_Split                            0                       0
# B_win_by_Decision_Unanimous                        1                       3
# B_win_by_KO/TKO                                    0                       0
# B_win_by_Submission                                0                       1
# B_win_by_TKO_Doctor_Stoppage                       0                       0
# B_wins                                             1                       4
# B_Stance                                    Southpaw                Orthodox
# B_Height_cms                                  180.34                   165.1
# B_Reach_cms                                   185.42                  162.56
# B_Weight_lbs                                     250                     115
# R_current_lose_streak                              1                       0
# R_current_win_streak                               0                       4
# R_draw                                             0                       0
# R_avg_BODY_att                                  7.75                    8.75
# R_avg_BODY_landed                               6.75                     7.5
# R_avg_CLINCH_att                                  11                       3
# R_avg_CLINCH_landed                             7.25                    2.25
# R_avg_DISTANCE_att                             50.75                   12.75
# R_avg_DISTANCE_landed                          24.75                    4.75
# R_avg_GROUND_att                                 0.5                   42.25
# R_avg_GROUND_landed                              0.5                   35.75
# R_avg_HEAD_att                                 50.75                   44.75
# R_avg_HEAD_landed                              22.75                   31.25
# R_avg_KD                                         0.5                       0
# R_avg_LEG_att                                   3.75                     4.5
# R_avg_LEG_landed                                   3                       4
# R_avg_PASS                                      0.25                    7.75
# R_avg_REV                                          0                       0
# R_avg_SIG_STR_att                              62.25                      58
# R_avg_SIG_STR_landed                            32.5                   42.75
# R_avg_SIG_STR_pct                              0.545                  0.6375
# R_avg_SUB_ATT                                      0                     0.5
# R_avg_TD_att                                     0.5                     5.5
# R_avg_TD_landed                                    0                     4.5
# R_avg_TD_pct                                       0                  0.8175
# R_avg_TOTAL_STR_att                             63.5                   101.5
# R_avg_TOTAL_STR_landed                         32.75                    80.5
# R_longest_win_streak                               3                       4
# R_losses                                           1                       0
# R_avg_opp_BODY_att                              6.25                       3
# R_avg_opp_BODY_landed                           4.75                    2.25
# R_avg_opp_CLINCH_att                             4.5                     3.5
# R_avg_opp_CLINCH_landed                          3.5                       3
# R_avg_opp_DISTANCE_att                         42.75                    5.75
# R_avg_opp_DISTANCE_landed                      16.25                       2
# R_avg_opp_GROUND_att                            7.75                       2
# R_avg_opp_GROUND_landed                         2.75                     1.5
# R_avg_opp_HEAD_att                             43.25                       8
# R_avg_opp_HEAD_landed                             14                       4
# R_avg_opp_KD                                    0.25                       0
# R_avg_opp_LEG_att                                5.5                    0.25
# R_avg_opp_LEG_landed                            3.75                    0.25
# R_avg_opp_PASS                                  0.75                       0
# R_avg_opp_REV                                      0                     0.5
# R_avg_opp_SIG_STR_att                             55                   11.25
# R_avg_opp_SIG_STR_landed                        22.5                     6.5
# R_avg_opp_SIG_STR_pct                         0.3975                    0.54
# R_avg_opp_SUB_ATT                                  0                    0.75
# R_avg_opp_TD_att                                   1                     0.5
# R_avg_opp_TD_landed                                0                       0
# R_avg_opp_TD_pct                                   0                       0
# R_avg_opp_TOTAL_STR_att                         60.5                      38
# R_avg_opp_TOTAL_STR_landed                     27.75                    26.5
# R_total_rounds_fought                              7                       8
# R_total_time_fought(seconds)                  440.75                     540
# R_total_title_bouts                                0                       1
# R_win_by_Decision_Majority                         0                       0
# R_win_by_Decision_Split                            0                       0
# R_win_by_Decision_Unanimous                        1                       1
# R_win_by_KO/TKO                                    2                       1
# R_win_by_Submission                                0                       2
# R_win_by_TKO_Doctor_Stoppage                       0                       0
# R_wins                                             3                       4
# R_Stance                                    Southpaw                     NaN
# R_Height_cms                                  187.96                   165.1
# R_Reach_cms                                    190.5                  167.64
# R_Weight_lbs                                     264                     115
# B_age                                             32                      33
# R_age                                             26                      28
#
#                                                 6                       7     \
# R_fighter                          Aljamain Sterling   Karolina Kowalkiewicz
# B_fighter                               Pedro Munhoz            Alexa Grasso
# Referee                                 Marc Goddard         Kevin MacDonald
# date                                      2019-06-08              2019-06-08
# location                      Chicago, Illinois, USA  Chicago, Illinois, USA
# Winner                                           Red                    Blue
# title_bout                                     False                   False
# weight_class                            Bantamweight     Women's Strawweight
# no_of_rounds                                       3                       3
# B_current_lose_streak                              0                       1
# B_current_win_streak                               3                       0
# B_draw                                             0                       0
# B_avg_BODY_att                                    15                   16.25
# B_avg_BODY_landed                            7.41667                      11
# B_avg_CLINCH_att                             6.08333                    17.5
# B_avg_CLINCH_landed                          3.41667                   11.25
# B_avg_DISTANCE_att                           84.9167                  105.75
# B_avg_DISTANCE_landed                        34.6667                      40
# B_avg_GROUND_att                             5.08333                       3
# B_avg_GROUND_landed                          3.41667                     2.5
# B_avg_HEAD_att                               66.5833                   94.25
# B_avg_HEAD_landed                                 24                   29.75
# B_avg_KD                                    0.416667                       0
# B_avg_LEG_att                                   14.5                   15.75
# B_avg_LEG_landed                             10.0833                      13
# B_avg_PASS                                  0.583333                    0.25
# B_avg_REV                                  0.0833333                    0.25
# B_avg_SIG_STR_att                            96.0833                  126.25
# B_avg_SIG_STR_landed                            41.5                   53.75
# B_avg_SIG_STR_pct                           0.499167                  0.5025
# B_avg_SUB_ATT                               0.666667                    0.25
# B_avg_TD_att                                    2.75                     0.5
# B_avg_TD_landed                             0.583333                    0.25
# B_avg_TD_pct                                0.233333                   0.125
# B_avg_TOTAL_STR_att                          102.667                   165.5
# B_avg_TOTAL_STR_landed                          47.5                    87.5
# B_longest_win_streak                               4                       1
# B_losses                                           4                       2
# B_avg_opp_BODY_att                           13.1667                   18.75
# B_avg_opp_BODY_landed                           7.25                    10.5
# B_avg_opp_CLINCH_att                         2.66667                       8
# B_avg_opp_CLINCH_landed                      1.33333                    6.25
# B_avg_opp_DISTANCE_att                       103.167                     101
# B_avg_opp_DISTANCE_landed                    41.6667                      27
# B_avg_opp_GROUND_att                         1.66667                    4.75
# B_avg_opp_GROUND_landed                      1.16667                     3.5
# B_avg_opp_HEAD_att                           88.8333                      90
# B_avg_opp_HEAD_landed                        32.3333                    23.5
# B_avg_opp_KD                                       0                       0
# B_avg_opp_LEG_att                                5.5                       5
# B_avg_opp_LEG_landed                         4.58333                    2.75
# B_avg_opp_PASS                             0.0833333                    2.75
# B_avg_opp_REV                                      0                    0.25
# B_avg_opp_SIG_STR_att                          107.5                  113.75
# B_avg_opp_SIG_STR_landed                     44.1667                   36.75
# B_avg_opp_SIG_STR_pct                         0.4025                   0.325
# B_avg_opp_SUB_ATT                                  0                    0.25
# B_avg_opp_TD_att                             2.16667                     5.5
# B_avg_opp_TD_landed                              0.5                       2
# B_avg_opp_TD_pct                            0.194167                    0.38
# B_avg_opp_TOTAL_STR_att                      110.333                  132.75
# B_avg_opp_TOTAL_STR_landed                      46.5                   53.75
# B_total_rounds_fought                             23                      10
# B_total_time_fought(seconds)                  495.25                     716
# B_total_title_bouts                                0                       0
# B_win_by_Decision_Majority                         0                       0
# B_win_by_Decision_Split                            0                       1
# B_win_by_Decision_Unanimous                        2                       1
# B_win_by_KO/TKO                                    3                       0
# B_win_by_Submission                                3                       0
# B_win_by_TKO_Doctor_Stoppage                       0                       0
# B_wins                                             8                       2
# B_Stance                                    Orthodox                Orthodox
# B_Height_cms                                  167.64                   165.1
# B_Reach_cms                                    165.1                  167.64
# B_Weight_lbs                                     135                     115
# R_current_lose_streak                              0                       2
# R_current_win_streak                               3                       0
# R_draw                                             0                       0
# R_avg_BODY_att                               25.1667                 25.2222
# R_avg_BODY_landed                              18.25                 17.5556
# R_avg_CLINCH_att                                  14                 27.5556
# R_avg_CLINCH_landed                          11.0833                 20.7778
# R_avg_DISTANCE_att                           72.5833                 155.778
# R_avg_DISTANCE_landed                        29.4167                 49.7778
# R_avg_GROUND_att                             16.0833                 3.77778
# R_avg_GROUND_landed                            11.75                       3
# R_avg_HEAD_att                                    63                     149
# R_avg_HEAD_landed                            23.3333                 46.7778
# R_avg_KD                                           0                       0
# R_avg_LEG_att                                   14.5                 12.8889
# R_avg_LEG_landed                             10.6667                 9.22222
# R_avg_PASS                                       1.5                0.777778
# R_avg_REV                                  0.0833333                0.111111
# R_avg_SIG_STR_att                            102.667                 187.111
# R_avg_SIG_STR_landed                           52.25                 73.5556
# R_avg_SIG_STR_pct                               0.49                    0.38
# R_avg_SUB_ATT                                   0.75                       0
# R_avg_TD_att                                 5.33333                0.777778
# R_avg_TD_landed                                 1.75                0.111111
# R_avg_TD_pct                                  0.4175               0.0555556
# R_avg_TOTAL_STR_att                          138.333                 211.222
# R_avg_TOTAL_STR_landed                         85.75                      95
# R_longest_win_streak                               4                       3
# R_losses                                           3                       4
# R_avg_opp_BODY_att                           8.91667                 26.2222
# R_avg_opp_BODY_landed                        4.66667                 14.6667
# R_avg_opp_CLINCH_att                            5.75                 20.5556
# R_avg_opp_CLINCH_landed                            4                 14.1111
# R_avg_opp_DISTANCE_att                            51                 133.111
# R_avg_opp_DISTANCE_landed                    12.9167                 51.6667
# R_avg_opp_GROUND_att                         1.83333                 1.66667
# R_avg_opp_GROUND_landed                      1.16667                 1.55556
# R_avg_opp_HEAD_att                           43.4167                 110.111
# R_avg_opp_HEAD_landed                        8.91667                 38.2222
# R_avg_opp_KD                                    0.25                0.111111
# R_avg_opp_LEG_att                               6.25                      19
# R_avg_opp_LEG_landed                             4.5                 14.4444
# R_avg_opp_PASS                              0.833333                0.555556
# R_avg_opp_REV                              0.0833333                0.111111
# R_avg_opp_SIG_STR_att                        58.5833                 155.333
# R_avg_opp_SIG_STR_landed                     18.0833                 67.3333
# R_avg_opp_SIG_STR_pct                       0.305833                0.414444
# R_avg_opp_SUB_ATT                          0.0833333                0.222222
# R_avg_opp_TD_att                                2.25                 4.77778
# R_avg_opp_TD_landed                          1.08333                0.777778
# R_avg_opp_TD_pct                            0.251667                0.271111
# R_avg_opp_TOTAL_STR_att                      80.5833                 170.778
# R_avg_opp_TOTAL_STR_landed                   37.8333                 81.8889
# R_total_rounds_fought                             32                      25
# R_total_time_fought(seconds)                 750.667                 800.111
# R_total_title_bouts                                0                       1
# R_win_by_Decision_Majority                         0                       0
# R_win_by_Decision_Split                            0                       2
# R_win_by_Decision_Unanimous                        5                       3
# R_win_by_KO/TKO                                    1                       0
# R_win_by_Submission                                3                       0
# R_win_by_TKO_Doctor_Stoppage                       0                       0
# R_wins                                             9                       5
# R_Stance                                    Orthodox                Orthodox
# R_Height_cms                                  170.18                  160.02
# R_Reach_cms                                   180.34                  162.56
# R_Weight_lbs                                     135                     115
# B_age                                             32                      25
# R_age                                             29                      33
#
#                                                 8                       9     \
# R_fighter                              Ricardo Lamas             Yan Xiaonan
# B_fighter                              Calvin Kattar             Angela Hill
# Referee                              Dan Miragliotta         Robert Madrigal
# date                                      2019-06-08              2019-06-08
# location                      Chicago, Illinois, USA  Chicago, Illinois, USA
# Winner                                          Blue                     Red
# title_bout                                     False                   False
# weight_class                           Featherweight     Women's Strawweight
# no_of_rounds                                       3                       3
# B_current_lose_streak                              0                       0
# B_current_win_streak                               1                       1
# B_draw                                             0                       0
# B_avg_BODY_att                                  7.25                    25.4
# B_avg_BODY_landed                               4.75                    17.9
# ...
# B_avg_opp_DISTANCE_att                          NaN                    NaN
# B_avg_opp_DISTANCE_landed                       NaN                    NaN
# B_avg_opp_GROUND_att                            NaN                    NaN
# B_avg_opp_GROUND_landed                         NaN                    NaN
# B_avg_opp_HEAD_att                              NaN                    NaN
# B_avg_opp_HEAD_landed                           NaN                    NaN
# B_avg_opp_KD                                    NaN                    NaN
# B_avg_opp_LEG_att                               NaN                    NaN
# B_avg_opp_LEG_landed                            NaN                    NaN
# B_avg_opp_PASS                                  NaN                    NaN
# B_avg_opp_REV                                   NaN                    NaN
# B_avg_opp_SIG_STR_att                           NaN                    NaN
# B_avg_opp_SIG_STR_landed                        NaN                    NaN
# B_avg_opp_SIG_STR_pct                           NaN                    NaN
# B_avg_opp_SUB_ATT                               NaN                    NaN
# B_avg_opp_TD_att                                NaN                    NaN
# B_avg_opp_TD_landed                             NaN                    NaN
# B_avg_opp_TD_pct                                NaN                    NaN
# B_avg_opp_TOTAL_STR_att                         NaN                    NaN
# B_avg_opp_TOTAL_STR_landed                      NaN                    NaN
# B_total_rounds_fought                             0                      0
# B_total_time_fought(seconds)                    NaN                    NaN
# B_total_title_bouts                               0                      0
# B_win_by_Decision_Majority                        0                      0
# B_win_by_Decision_Split                           0                      0
# B_win_by_Decision_Unanimous                       0                      0
# B_win_by_KO/TKO                                   0                      0
# B_win_by_Submission                               0                      0
# B_win_by_TKO_Doctor_Stoppage                      0                      0
# B_wins                                            0                      0
# B_Stance                                   Orthodox               Orthodox
# B_Height_cms                                 185.42                 195.58
# B_Reach_cms                                     NaN                    NaN
# B_Weight_lbs                                    196                    250
# R_current_lose_streak                             0                      0
# R_current_win_streak                              0                      0
# R_draw                                            0                      0
# R_avg_BODY_att                                  NaN                    NaN
# R_avg_BODY_landed                               NaN                    NaN
# R_avg_CLINCH_att                                NaN                    NaN
# R_avg_CLINCH_landed                             NaN                    NaN
# R_avg_DISTANCE_att                              NaN                    NaN
# R_avg_DISTANCE_landed                           NaN                    NaN
# R_avg_GROUND_att                                NaN                    NaN
# R_avg_GROUND_landed                             NaN                    NaN
# R_avg_HEAD_att                                  NaN                    NaN
# R_avg_HEAD_landed                               NaN                    NaN
# R_avg_KD                                        NaN                    NaN
# R_avg_LEG_att                                   NaN                    NaN
# R_avg_LEG_landed                                NaN                    NaN
# R_avg_PASS                                      NaN                    NaN
# R_avg_REV                                       NaN                    NaN
# R_avg_SIG_STR_att                               NaN                    NaN
# R_avg_SIG_STR_landed                            NaN                    NaN
# R_avg_SIG_STR_pct                               NaN                    NaN
# R_avg_SUB_ATT                                   NaN                    NaN
# R_avg_TD_att                                    NaN                    NaN
# R_avg_TD_landed                                 NaN                    NaN
# R_avg_TD_pct                                    NaN                    NaN
# R_avg_TOTAL_STR_att                             NaN                    NaN
# R_avg_TOTAL_STR_landed                          NaN                    NaN
# R_longest_win_streak                              0                      0
# R_losses                                          0                      0
# R_avg_opp_BODY_att                              NaN                    NaN
# R_avg_opp_BODY_landed                           NaN                    NaN
# R_avg_opp_CLINCH_att                            NaN                    NaN
# R_avg_opp_CLINCH_landed                         NaN                    NaN
# R_avg_opp_DISTANCE_att                          NaN                    NaN
# R_avg_opp_DISTANCE_landed                       NaN                    NaN
# R_avg_opp_GROUND_att                            NaN                    NaN
# R_avg_opp_GROUND_landed                         NaN                    NaN
# R_avg_opp_HEAD_att                              NaN                    NaN
# R_avg_opp_HEAD_landed                           NaN                    NaN
# R_avg_opp_KD                                    NaN                    NaN
# R_avg_opp_LEG_att                               NaN                    NaN
# R_avg_opp_LEG_landed                            NaN                    NaN
# R_avg_opp_PASS                                  NaN                    NaN
# R_avg_opp_REV                                   NaN                    NaN
# R_avg_opp_SIG_STR_att                           NaN                    NaN
# R_avg_opp_SIG_STR_landed                        NaN                    NaN
# R_avg_opp_SIG_STR_pct                           NaN                    NaN
# R_avg_opp_SUB_ATT                               NaN                    NaN
# R_avg_opp_TD_att                                NaN                    NaN
# R_avg_opp_TD_landed                             NaN                    NaN
# R_avg_opp_TD_pct                                NaN                    NaN
# R_avg_opp_TOTAL_STR_att                         NaN                    NaN
# R_avg_opp_TOTAL_STR_landed                      NaN                    NaN
# R_total_rounds_fought                             0                      0
# R_total_time_fought(seconds)                    NaN                    NaN
# R_total_title_bouts                               0                      0
# R_win_by_Decision_Majority                        0                      0
# R_win_by_Decision_Split                           0                      0
# R_win_by_Decision_Unanimous                       0                      0
# R_win_by_KO/TKO                                   0                      0
# R_win_by_Submission                               0                      0
# R_win_by_TKO_Doctor_Stoppage                      0                      0
# R_wins                                            0                      0
# R_Stance                                   Southpaw               Orthodox
# R_Height_cms                                 185.42                 193.04
# R_Reach_cms                                     NaN                    NaN
# R_Weight_lbs                                    175                    275
# B_age                                            30                    NaN
# R_age                                            26                    NaN
#
#                                                5143
# R_fighter                            Gerard Gordeau
# B_fighter                                Teila Tuli
# Referee                        Joao Alberto Barreto
# date                                     1993-11-12
# location                      Denver, Colorado, USA
# Winner                                          Red
# title_bout                                    False
# weight_class                            Open Weight
# no_of_rounds                                      1
# B_current_lose_streak                             0
# B_current_win_streak                              0
# B_draw                                            0
# B_avg_BODY_att                                  NaN
# B_avg_BODY_landed                               NaN
# B_avg_CLINCH_att                                NaN
# B_avg_CLINCH_landed                             NaN
# B_avg_DISTANCE_att                              NaN
# B_avg_DISTANCE_landed                           NaN
# B_avg_GROUND_att                                NaN
# B_avg_GROUND_landed                             NaN
# B_avg_HEAD_att                                  NaN
# B_avg_HEAD_landed                               NaN
# B_avg_KD                                        NaN
# B_avg_LEG_att                                   NaN
# B_avg_LEG_landed                                NaN
# B_avg_PASS                                      NaN
# B_avg_REV                                       NaN
# B_avg_SIG_STR_att                               NaN
# B_avg_SIG_STR_landed                            NaN
# B_avg_SIG_STR_pct                               NaN
# B_avg_SUB_ATT                                   NaN
# B_avg_TD_att                                    NaN
# B_avg_TD_landed                                 NaN
# B_avg_TD_pct                                    NaN
# B_avg_TOTAL_STR_att                             NaN
# B_avg_TOTAL_STR_landed                          NaN
# B_longest_win_streak                              0
# B_losses                                          0
# B_avg_opp_BODY_att                              NaN
# B_avg_opp_BODY_landed                           NaN
# B_avg_opp_CLINCH_att                            NaN
# B_avg_opp_CLINCH_landed                         NaN
# B_avg_opp_DISTANCE_att                          NaN
# B_avg_opp_DISTANCE_landed                       NaN
# B_avg_opp_GROUND_att                            NaN
# B_avg_opp_GROUND_landed                         NaN
# B_avg_opp_HEAD_att                              NaN
# B_avg_opp_HEAD_landed                           NaN
# B_avg_opp_KD                                    NaN
# B_avg_opp_LEG_att                               NaN
# B_avg_opp_LEG_landed                            NaN
# B_avg_opp_PASS                                  NaN
# B_avg_opp_REV                                   NaN
# B_avg_opp_SIG_STR_att                           NaN
# B_avg_opp_SIG_STR_landed                        NaN
# B_avg_opp_SIG_STR_pct                           NaN
# B_avg_opp_SUB_ATT                               NaN
# B_avg_opp_TD_att                                NaN
# B_avg_opp_TD_landed                             NaN
# B_avg_opp_TD_pct                                NaN
# B_avg_opp_TOTAL_STR_att                         NaN
# B_avg_opp_TOTAL_STR_landed                      NaN
# B_total_rounds_fought                             0
# B_total_time_fought(seconds)                    NaN
# B_total_title_bouts                               0
# B_win_by_Decision_Majority                        0
# B_win_by_Decision_Split                           0
# B_win_by_Decision_Unanimous                       0
# B_win_by_KO/TKO                                   0
# B_win_by_Submission                               0
# B_win_by_TKO_Doctor_Stoppage                      0
# B_wins                                            0
# B_Stance                                   Orthodox
# B_Height_cms                                 182.88
# B_Reach_cms                                     NaN
# B_Weight_lbs                                    430
# R_current_lose_streak                             0
# R_current_win_streak                              0
# R_draw                                            0
# R_avg_BODY_att                                  NaN
# R_avg_BODY_landed                               NaN
# R_avg_CLINCH_att                                NaN
# R_avg_CLINCH_landed                             NaN
# R_avg_DISTANCE_att                              NaN
# R_avg_DISTANCE_landed                           NaN
# R_avg_GROUND_att                                NaN
# R_avg_GROUND_landed                             NaN
# R_avg_HEAD_att                                  NaN
# R_avg_HEAD_landed                               NaN
# R_avg_KD                                        NaN
# R_avg_LEG_att                                   NaN
# R_avg_LEG_landed                                NaN
# R_avg_PASS                                      NaN
# R_avg_REV                                       NaN
# R_avg_SIG_STR_att                               NaN
# R_avg_SIG_STR_landed                            NaN
# R_avg_SIG_STR_pct                               NaN
# R_avg_SUB_ATT                                   NaN
# R_avg_TD_att                                    NaN
# R_avg_TD_landed                                 NaN
# R_avg_TD_pct                                    NaN
# R_avg_TOTAL_STR_att                             NaN
# R_avg_TOTAL_STR_landed                          NaN
# R_longest_win_streak                              0
# R_losses                                          0
# R_avg_opp_BODY_att                              NaN
# R_avg_opp_BODY_landed                           NaN
# R_avg_opp_CLINCH_att                            NaN
# R_avg_opp_CLINCH_landed                         NaN
# R_avg_opp_DISTANCE_att                          NaN
# R_avg_opp_DISTANCE_landed                       NaN
# R_avg_opp_GROUND_att                            NaN
# R_avg_opp_GROUND_landed                         NaN
# R_avg_opp_HEAD_att                              NaN
# R_avg_opp_HEAD_landed                           NaN
# R_avg_opp_KD                                    NaN
# R_avg_opp_LEG_att                               NaN
# R_avg_opp_LEG_landed                            NaN
# R_avg_opp_PASS                                  NaN
# R_avg_opp_REV                                   NaN
# R_avg_opp_SIG_STR_att                           NaN
# R_avg_opp_SIG_STR_landed                        NaN
# R_avg_opp_SIG_STR_pct                           NaN
# R_avg_opp_SUB_ATT                               NaN
# R_avg_opp_TD_att                                NaN
# R_avg_opp_TD_landed                             NaN
# R_avg_opp_TD_pct                                NaN
# R_avg_opp_TOTAL_STR_att                         NaN
# R_avg_opp_TOTAL_STR_landed                      NaN
# R_total_rounds_fought                             0
# R_total_time_fought(seconds)                    NaN
# R_total_title_bouts                               0
# R_win_by_Decision_Majority                        0
# R_win_by_Decision_Split                           0
# R_win_by_Decision_Unanimous                       0
# R_win_by_KO/TKO                                   0
# R_win_by_Submission                               0
# R_win_by_TKO_Doctor_Stoppage                      0
# R_wins                                            0
# R_Stance                                   Orthodox
# R_Height_cms                                 195.58
# R_Reach_cms                                     NaN
# R_Weight_lbs                                    216
# B_age                                            24
# R_age                                            34
#
# [145 rows x 5144 columns]

# %% [markdown]
# ## Handle missing values

# %% [markdown]
# ### Get insights about the missing values

# %%
df.isna().sum()
# Out:
# R_fighter                          0
# B_fighter                          0
# Referee                           23
# date                               0
# location                           0
# Winner                             0
# title_bout                         0
# weight_class                       0
# no_of_rounds                       0
# B_current_lose_streak              0
# B_current_win_streak               0
# B_draw                             0
# B_avg_BODY_att                  1265
# B_avg_BODY_landed               1265
# B_avg_CLINCH_att                1265
# B_avg_CLINCH_landed             1265
# B_avg_DISTANCE_att              1265
# B_avg_DISTANCE_landed           1265
# B_avg_GROUND_att                1265
# B_avg_GROUND_landed             1265
# B_avg_HEAD_att                  1265
# B_avg_HEAD_landed               1265
# B_avg_KD                        1265
# B_avg_LEG_att                   1265
# B_avg_LEG_landed                1265
# B_avg_PASS                      1265
# B_avg_REV                       1265
# B_avg_SIG_STR_att               1265
# B_avg_SIG_STR_landed            1265
# B_avg_SIG_STR_pct               1265
# B_avg_SUB_ATT                   1265
# B_avg_TD_att                    1265
# B_avg_TD_landed                 1265
# B_avg_TD_pct                    1265
# B_avg_TOTAL_STR_att             1265
# B_avg_TOTAL_STR_landed          1265
# B_longest_win_streak               0
# B_losses                           0
# B_avg_opp_BODY_att              1265
# B_avg_opp_BODY_landed           1265
# B_avg_opp_CLINCH_att            1265
# B_avg_opp_CLINCH_landed         1265
# B_avg_opp_DISTANCE_att          1265
# B_avg_opp_DISTANCE_landed       1265
# B_avg_opp_GROUND_att            1265
# B_avg_opp_GROUND_landed         1265
# B_avg_opp_HEAD_att              1265
# B_avg_opp_HEAD_landed           1265
# B_avg_opp_KD                    1265
# B_avg_opp_LEG_att               1265
# B_avg_opp_LEG_landed            1265
# B_avg_opp_PASS                  1265
# B_avg_opp_REV                   1265
# B_avg_opp_SIG_STR_att           1265
# B_avg_opp_SIG_STR_landed        1265
# B_avg_opp_SIG_STR_pct           1265
# B_avg_opp_SUB_ATT               1265
# B_avg_opp_TD_att                1265
# B_avg_opp_TD_landed             1265
# B_avg_opp_TD_pct                1265
# B_avg_opp_TOTAL_STR_att         1265
# B_avg_opp_TOTAL_STR_landed      1265
# B_total_rounds_fought              0
# B_total_time_fought(seconds)    1265
# B_total_title_bouts                0
# B_win_by_Decision_Majority         0
# B_win_by_Decision_Split            0
# B_win_by_Decision_Unanimous        0
# B_win_by_KO/TKO                    0
# B_win_by_Submission                0
# B_win_by_TKO_Doctor_Stoppage       0
# B_wins                             0
# B_Stance                         159
# B_Height_cms                       8
# B_Reach_cms                      666
# B_Weight_lbs                       6
# R_current_lose_streak              0
# R_current_win_streak               0
# R_draw                             0
# R_avg_BODY_att                   650
# R_avg_BODY_landed                650
# R_avg_CLINCH_att                 650
# R_avg_CLINCH_landed              650
# R_avg_DISTANCE_att               650
# R_avg_DISTANCE_landed            650
# R_avg_GROUND_att                 650
# R_avg_GROUND_landed              650
# R_avg_HEAD_att                   650
# R_avg_HEAD_landed                650
# R_avg_KD                         650
# R_avg_LEG_att                    650
# R_avg_LEG_landed                 650
# R_avg_PASS                       650
# R_avg_REV                        650
# R_avg_SIG_STR_att                650
# R_avg_SIG_STR_landed             650
# R_avg_SIG_STR_pct                650
# R_avg_SUB_ATT                    650
# R_avg_TD_att                     650
# R_avg_TD_landed                  650
# R_avg_TD_pct                     650
# R_avg_TOTAL_STR_att              650
# R_avg_TOTAL_STR_landed           650
# R_longest_win_streak               0
# R_losses                           0
# R_avg_opp_BODY_att               650
# R_avg_opp_BODY_landed            650
# R_avg_opp_CLINCH_att             650
# R_avg_opp_CLINCH_landed          650
# R_avg_opp_DISTANCE_att           650
# R_avg_opp_DISTANCE_landed        650
# R_avg_opp_GROUND_att             650
# R_avg_opp_GROUND_landed          650
# R_avg_opp_HEAD_att               650
# R_avg_opp_HEAD_landed            650
# R_avg_opp_KD                     650
# R_avg_opp_LEG_att                650
# R_avg_opp_LEG_landed             650
# R_avg_opp_PASS                   650
# R_avg_opp_REV                    650
# R_avg_opp_SIG_STR_att            650
# R_avg_opp_SIG_STR_landed         650
# R_avg_opp_SIG_STR_pct            650
# R_avg_opp_SUB_ATT                650
# R_avg_opp_TD_att                 650
# R_avg_opp_TD_landed              650
# R_avg_opp_TD_pct                 650
# R_avg_opp_TOTAL_STR_att          650
# R_avg_opp_TOTAL_STR_landed       650
# R_total_rounds_fought              0
# R_total_time_fought(seconds)     650
# R_total_title_bouts                0
# R_win_by_Decision_Majority         0
# R_win_by_Decision_Split            0
# R_win_by_Decision_Unanimous        0
# R_win_by_KO/TKO                    0
# R_win_by_Submission                0
# R_win_by_TKO_Doctor_Stoppage       0
# R_wins                             0
# R_Stance                         134
# R_Height_cms                       4
# R_Reach_cms                      316
# R_Weight_lbs                       3
# B_age                            172
# R_age                             64
# dtype: int64

# %%
# used before finding the set_option('display.max_rows', 200) option
def nan_cols():
    print ("NaN columns")
    for col in df:
        if pd.isnull(df[col]).sum() > 0:
            print (col, pd.isnull(df[col]).sum())

# %%
# reset to default max
pd.set_option('display.max_rows', 0)
pd.set_option('display.max_columns', 0)

# %% [markdown]
# ### Drop rows with no history
# Each row in the dataset is a aggregation of previous fights. If metrics are NaN, then it is of no use for us. Could be the first fight at all. Delete those rows.

# %%
# are there NaN for total rounds?
df[(df.B_total_rounds_fought.isna()) | (df.R_total_rounds_fought.isna())]
# Out:
# Empty DataFrame
# Columns: [R_fighter, B_fighter, Referee, date, location, Winner, title_bout, weight_class, no_of_rounds, B_current_lose_streak, B_current_win_streak, B_draw, B_avg_BODY_att, B_avg_BODY_landed, B_avg_CLINCH_att, B_avg_CLINCH_landed, B_avg_DISTANCE_att, B_avg_DISTANCE_landed, B_avg_GROUND_att, B_avg_GROUND_landed, B_avg_HEAD_att, B_avg_HEAD_landed, B_avg_KD, B_avg_LEG_att, B_avg_LEG_landed, B_avg_PASS, B_avg_REV, B_avg_SIG_STR_att, B_avg_SIG_STR_landed, B_avg_SIG_STR_pct, B_avg_SUB_ATT, B_avg_TD_att, B_avg_TD_landed, B_avg_TD_pct, B_avg_TOTAL_STR_att, B_avg_TOTAL_STR_landed, B_longest_win_streak, B_losses, B_avg_opp_BODY_att, B_avg_opp_BODY_landed, B_avg_opp_CLINCH_att, B_avg_opp_CLINCH_landed, B_avg_opp_DISTANCE_att, B_avg_opp_DISTANCE_landed, B_avg_opp_GROUND_att, B_avg_opp_GROUND_landed, B_avg_opp_HEAD_att, B_avg_opp_HEAD_landed, B_avg_opp_KD, B_avg_opp_LEG_att, B_avg_opp_LEG_landed, B_avg_opp_PASS, B_avg_opp_REV, B_avg_opp_SIG_STR_att, B_avg_opp_SIG_STR_landed, B_avg_opp_SIG_STR_pct, B_avg_opp_SUB_ATT, B_avg_opp_TD_att, B_avg_opp_TD_landed, B_avg_opp_TD_pct, B_avg_opp_TOTAL_STR_att, B_avg_opp_TOTAL_STR_landed, B_total_rounds_fought, B_total_time_fought(seconds), B_total_title_bouts, B_win_by_Decision_Majority, B_win_by_Decision_Split, B_win_by_Decision_Unanimous, B_win_by_KO/TKO, B_win_by_Submission, B_win_by_TKO_Doctor_Stoppage, B_wins, B_Stance, B_Height_cms, B_Reach_cms, B_Weight_lbs, R_current_lose_streak, R_current_win_streak, R_draw, R_avg_BODY_att, R_avg_BODY_landed, R_avg_CLINCH_att, R_avg_CLINCH_landed, R_avg_DISTANCE_att, R_avg_DISTANCE_landed, R_avg_GROUND_att, R_avg_GROUND_landed, R_avg_HEAD_att, R_avg_HEAD_landed, R_avg_KD, R_avg_LEG_att, R_avg_LEG_landed, R_avg_PASS, R_avg_REV, R_avg_SIG_STR_att, R_avg_SIG_STR_landed, R_avg_SIG_STR_pct, R_avg_SUB_ATT, R_avg_TD_att, R_avg_TD_landed, ...]
# Index: []
#
# [0 rows x 145 columns]

# %%
# which cols are NaN?
nan_cols()
# Out:
# NaN columns
# Referee 23
# B_avg_BODY_att 1265
# B_avg_BODY_landed 1265
# B_avg_CLINCH_att 1265
# B_avg_CLINCH_landed 1265
# B_avg_DISTANCE_att 1265
# B_avg_DISTANCE_landed 1265
# B_avg_GROUND_att 1265
# B_avg_GROUND_landed 1265
# B_avg_HEAD_att 1265
# B_avg_HEAD_landed 1265
# B_avg_KD 1265
# B_avg_LEG_att 1265
# B_avg_LEG_landed 1265
# B_avg_PASS 1265
# B_avg_REV 1265
# B_avg_SIG_STR_att 1265
# B_avg_SIG_STR_landed 1265
# B_avg_SIG_STR_pct 1265
# B_avg_SUB_ATT 1265
# B_avg_TD_att 1265
# B_avg_TD_landed 1265
# B_avg_TD_pct 1265
# B_avg_TOTAL_STR_att 1265
# B_avg_TOTAL_STR_landed 1265
# B_avg_opp_BODY_att 1265
# B_avg_opp_BODY_landed 1265
# B_avg_opp_CLINCH_att 1265
# B_avg_opp_CLINCH_landed 1265
# B_avg_opp_DISTANCE_att 1265
# B_avg_opp_DISTANCE_landed 1265
# B_avg_opp_GROUND_att 1265
# B_avg_opp_GROUND_landed 1265
# B_avg_opp_HEAD_att 1265
# B_avg_opp_HEAD_landed 1265
# B_avg_opp_KD 1265
# B_avg_opp_LEG_att 1265
# B_avg_opp_LEG_landed 1265
# B_avg_opp_PASS 1265
# B_avg_opp_REV 1265
# B_avg_opp_SIG_STR_att 1265
# B_avg_opp_SIG_STR_landed 1265
# B_avg_opp_SIG_STR_pct 1265
# B_avg_opp_SUB_ATT 1265
# B_avg_opp_TD_att 1265
# B_avg_opp_TD_landed 1265
# B_avg_opp_TD_pct 1265
# B_avg_opp_TOTAL_STR_att 1265
# B_avg_opp_TOTAL_STR_landed 1265
# B_total_time_fought(seconds) 1265
# B_Stance 159
# B_Height_cms 8
# B_Reach_cms 666
# B_Weight_lbs 6
# R_avg_BODY_att 650
# R_avg_BODY_landed 650
# R_avg_CLINCH_att 650
# R_avg_CLINCH_landed 650
# R_avg_DISTANCE_att 650
# R_avg_DISTANCE_landed 650
# R_avg_GROUND_att 650
# R_avg_GROUND_landed 650
# R_avg_HEAD_att 650
# R_avg_HEAD_landed 650
# R_avg_KD 650
# R_avg_LEG_att 650
# R_avg_LEG_landed 650
# R_avg_PASS 650
# R_avg_REV 650
# R_avg_SIG_STR_att 650
# R_avg_SIG_STR_landed 650
# R_avg_SIG_STR_pct 650
# R_avg_SUB_ATT 650
# R_avg_TD_att 650
# R_avg_TD_landed 650
# R_avg_TD_pct 650
# R_avg_TOTAL_STR_att 650
# R_avg_TOTAL_STR_landed 650
# R_avg_opp_BODY_att 650
# R_avg_opp_BODY_landed 650
# R_avg_opp_CLINCH_att 650
# R_avg_opp_CLINCH_landed 650
# R_avg_opp_DISTANCE_att 650
# R_avg_opp_DISTANCE_landed 650
# R_avg_opp_GROUND_att 650
# R_avg_opp_GROUND_landed 650
# R_avg_opp_HEAD_att 650
# R_avg_opp_HEAD_landed 650
# R_avg_opp_KD 650
# R_avg_opp_LEG_att 650
# R_avg_opp_LEG_landed 650
# R_avg_opp_PASS 650
# R_avg_opp_REV 650
# R_avg_opp_SIG_STR_att 650
# R_avg_opp_SIG_STR_landed 650
# R_avg_opp_SIG_STR_pct 650
# R_avg_opp_SUB_ATT 650
# R_avg_opp_TD_att 650
# R_avg_opp_TD_landed 650
# R_avg_opp_TD_pct 650
# R_avg_opp_TOTAL_STR_att 650
# R_avg_opp_TOTAL_STR_landed 650
# R_total_time_fought(seconds) 650
# R_Stance 134
# R_Height_cms 4
# R_Reach_cms 316
# R_Weight_lbs 3
# B_age 172
# R_age 64

# %%
# delete records with 0 aggregated rounds which should eliminate most of the NaN values as well
df = df[(df.B_total_rounds_fought > 0) & (df.R_total_rounds_fought > 0)]

# %%
nan_cols()
# Out:
# NaN columns
# Referee 16
# B_Stance 74
# B_Height_cms 1
# B_Reach_cms 260
# R_Stance 76
# R_Reach_cms 111
# B_age 56
# R_age 12

# %% [markdown]
# ### Try to guess Reach from Height

# %%
px.scatter(df, x="B_Height_cms", y="B_Reach_cms", range_x=[150,220], range_y=[150,220], width=600, height=600)

# %%
px.scatter(df, x="R_Height_cms", y="R_Reach_cms", range_x=[150,220], range_y=[150,220], width=600, height=600)

# %%
# get a feeling about the deviation between reach and height
(df["R_Height_cms"] - df["R_Reach_cms"]).abs().fillna("0").astype("float64").describe()
# Out:
# count    3648.000000
# mean        5.105066
# std         3.992268
# min         0.000000
# 25%         2.540000
# 50%         5.080000
# 75%         7.620000
# max        22.860000
# dtype: float64

# %%
(df["B_Height_cms"] - df["B_Reach_cms"]).abs().fillna("0").astype("float64").describe()
# Out:
# count    3648.000000
# mean        4.768766
# std         3.987520
# min         0.000000
# 25%         2.540000
# 50%         5.080000
# 75%         7.620000
# max        20.320000
# dtype: float64

# %% [markdown]
# The correclation seems good enough. Only a few centimeters deviation. So this is our best guess.

# %% [markdown]
# ### Reach correlates with height - Fill missing values

# %%
df["R_Reach_cms"] = df["R_Reach_cms"].fillna(df["R_Height_cms"])
# Out:
# C:\Users\areinhofer\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["R_Reach_cms"].isna().sum()
# Out:
# 0

# %%
df["B_Reach_cms"] = df["B_Reach_cms"].fillna(df["B_Height_cms"])
# Out:
# C:\Users\areinhofer\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["R_Reach_cms"].isna().sum()
# Out:
# 0

# %%
nan_cols()
# Out:
# NaN columns
# Referee 16
# B_Stance 74
# B_Height_cms 1
# R_Stance 76
# B_age 56
# R_age 12

# %% [markdown]
# ### Get most frequent stands to fill missing values

# %%
df["B_Stance"].value_counts()
# Out:
# Orthodox       2727
# Southpaw        724
# Switch          116
# Open Stance       5
# Sideways          2
# Name: B_Stance, dtype: int64

# %%
df["B_Stance"].isnull().sum()
# Out:
# 74

# %%
df['R_Stance'].value_counts()
# Out:
# Orthodox       2695
# Southpaw        765
# Switch          100
# Open Stance      12
# Name: R_Stance, dtype: int64

# %%
df["R_Stance"].isnull().sum()
# Out:
# 76

# %% [markdown]
# Not many stances are missing. To use the most frequent one is reasonable.

# %%
# Fill most frequent stance for missing values
categorical_columns_missing = ["R_Stance", "B_Stance"]
impute_missing=SimpleImputer(missing_values=np.NaN, strategy='most_frequent')
df[categorical_columns_missing] = impute_missing.fit_transform(df[categorical_columns_missing])
# Out:
# C:\Users\areinhofer\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\areinhofer\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["B_Stance"].value_counts()
# Out:
# Orthodox       2801
# Southpaw        724
# Switch          116
# Open Stance       5
# Sideways          2
# Name: B_Stance, dtype: int64

# %%
df["B_Stance"].isnull().sum()
# Out:
# 0

# %%
df["R_Stance"].isnull().sum()
# Out:
# 0

# %%
# see what's left with NaN
nan_cols()
# Out:
# NaN columns
# Referee 16
# B_Height_cms 1
# B_age 56
# R_age 12

# %% [markdown]
# ### Get the median for the rest of the missing values

# %%
df = df.fillna(df.median())

# %%
nan_cols()
# Out:
# NaN columns
# Referee 16

# %% [markdown]
# ## Delete unneccesary data

# %% [markdown]
# ### Eliminate Draws, we don't want to predict them

# %%
df.Winner.value_counts()
# Out:
# Red     2380
# Blue    1212
# Draw      56
# Name: Winner, dtype: int64

# %%
df = df[df.Winner != "Draw"]

# %%
df = df.drop(["R_draw", "B_draw"], axis=1)

# %%
df.Winner.value_counts()
# Out:
# Red     2380
# Blue    1212
# Name: Winner, dtype: int64

# %%
df.shape
# Out:
# (3592, 143)

# %%
df.dtypes
# Out:
# R_fighter                        object
# B_fighter                        object
# Referee                          object
# date                             object
# location                         object
# Winner                           object
# title_bout                         bool
# weight_class                     object
# no_of_rounds                      int64
# B_current_lose_streak           float64
# B_current_win_streak            float64
# B_avg_BODY_att                  float64
#                                  ...
# R_win_by_Decision_Split         float64
# R_win_by_Decision_Unanimous     float64
# R_win_by_KO/TKO                 float64
# R_win_by_Submission             float64
# R_win_by_TKO_Doctor_Stoppage    float64
# R_wins                          float64
# R_Stance                         object
# R_Height_cms                    float64
# R_Reach_cms                     float64
# R_Weight_lbs                    float64
# B_age                           float64
# R_age                           float64
# Length: 143, dtype: object

# %% [markdown]
# ## Combine winners and fighter master data

# %%
df_fighter = pd.read_csv("../data/raw/UFC/raw_fighter_details.csv", sep=",")

# %%
#add prefix for later use
df_fighter = df_fighter.add_prefix('winner_')

# %%
df_fighter
# Out:
#          winner_fighter_name winner_Height  ... winner_Stance    winner_DOB
# 0                 AJ Fonseca         5' 4"  ...           NaN           NaN
# 1                AJ Matthews        5' 11"  ...           NaN           NaN
# 2                   AJ McKee        5' 10"  ...           NaN           NaN
# 3                  AJ Siscoe         5' 7"  ...           NaN           NaN
# 4                 Aalon Cruz         6' 0"  ...           NaN           NaN
# 5                Aaron Brink         6' 3"  ...      Orthodox  Nov 12, 1974
# 6                  Aaron Ely         5' 8"  ...           NaN  Mar 18, 1989
# 7              Aaron Jeffery         6' 2"  ...           NaN  Nov 14, 1992
# 8            Aaron Lanfranco           NaN  ...           NaN  Aug 26, 1986
# ...                      ...           ...  ...           ...           ...
# 3304               Zak Ottow        5' 11"  ...      Orthodox  Dec 22, 1986
# 3305            Zane Frazier         6' 5"  ...      Orthodox           NaN
# 3306  Zarah Fairn dos Santos        5' 10"  ...           NaN  Dec 12, 1986
# 3307            Zelg Galesic         6' 2"  ...      Orthodox  Feb 16, 1979
# 3308           Zelim Imadaev         6' 0"  ...      Orthodox  Jan 25, 1995
# 3309            Zhang Lipeng        5' 11"  ...      Southpaw  Mar 10, 1990
# 3310           Zoila Frausto         5' 4"  ...      Orthodox           NaN
# 3311              Zu Anyanwu         6' 1"  ...      Orthodox  Aug 05, 1981
# 3312        Zubaira Tukhugov         5' 8"  ...      Orthodox  Jan 15, 1991
#
# [3313 rows x 6 columns]

# %%
# copy fights df, to not influence output files
df_w_fighter = df.copy(deep=True)

# %%
# determine winner name and age
df_w_fighter['WinnerName'] = 'Unknown'
df_w_fighter['WinnerAge'] = 0

df_w_fighter.loc[df_w_fighter['Winner']=="Red", 'WinnerName'] = df_w_fighter.R_fighter
df_w_fighter.loc[df_w_fighter['Winner']=="Red", 'WinnerAge'] = df_w_fighter.R_age

df_w_fighter.loc[df_w_fighter['Winner']=="Blue", 'WinnerName'] = df_w_fighter.B_fighter
df_w_fighter.loc[df_w_fighter['Winner']=="Blue", 'WinnerAge'] = df_w_fighter.B_age

# %%
df_w_fighter[["WinnerName", "WinnerAge", "Winner", "R_fighter", "R_age", "B_fighter", "B_age", "title_bout"]]
# Out:
#                 WinnerName  WinnerAge Winner  ...       B_fighter  B_age title_bout
# 0             Henry Cejudo       32.0    Red  ...   Marlon Moraes   31.0       True
# 1     Valentina Shevchenko       31.0    Red  ...     Jessica Eye   32.0       True
# 2            Tony Ferguson       35.0    Red  ...  Donald Cerrone   36.0      False
# 3                 Petr Yan       26.0   Blue  ...        Petr Yan   26.0      False
# 4            Blagoy Ivanov       32.0   Blue  ...   Blagoy Ivanov   32.0      False
# 5           Tatiana Suarez       28.0    Red  ...   Nina Ansaroff   33.0      False
# 6        Aljamain Sterling       29.0    Red  ...    Pedro Munhoz   32.0      False
# 7             Alexa Grasso       25.0   Blue  ...    Alexa Grasso   25.0      False
# 8            Calvin Kattar       31.0   Blue  ...   Calvin Kattar   31.0      False
# ...                    ...        ...    ...  ...             ...    ...        ...
# 5121          Royce Gracie       27.0    Red  ...   Patrick Smith   30.0       True
# 5122          Royce Gracie       27.0    Red  ...   Remco Pardoel   29.0      False
# 5123         Patrick Smith       30.0    Red  ...   Johnny Rhodes   29.0      False
# 5124          Royce Gracie       27.0    Red  ...   Jason DeLucia   24.0      False
# 5125         Remco Pardoel       30.0    Red  ...    Orlando Wiet   29.0      False
# 5127         Patrick Smith       30.0    Red  ...    Scott Morris   29.0      False
# 5136          Royce Gracie       26.0    Red  ...  Gerard Gordeau   34.0       True
# 5138          Royce Gracie       26.0    Red  ...    Ken Shamrock   29.0      False
# 5139        Gerard Gordeau       34.0    Red  ...    Kevin Rosier   29.0      False
#
# [3592 rows x 8 columns]

# %%
df_w_fighter[(df_w_fighter.WinnerName == "Unknown") | (df_w_fighter.WinnerAge <= 0.0)]
# Out:
# Empty DataFrame
# Columns: [R_fighter, B_fighter, Referee, date, location, Winner, title_bout, weight_class, no_of_rounds, B_current_lose_streak, B_current_win_streak, B_avg_BODY_att, B_avg_BODY_landed, B_avg_CLINCH_att, B_avg_CLINCH_landed, B_avg_DISTANCE_att, B_avg_DISTANCE_landed, B_avg_GROUND_att, B_avg_GROUND_landed, B_avg_HEAD_att, B_avg_HEAD_landed, B_avg_KD, B_avg_LEG_att, B_avg_LEG_landed, B_avg_PASS, B_avg_REV, B_avg_SIG_STR_att, B_avg_SIG_STR_landed, B_avg_SIG_STR_pct, B_avg_SUB_ATT, B_avg_TD_att, B_avg_TD_landed, B_avg_TD_pct, B_avg_TOTAL_STR_att, B_avg_TOTAL_STR_landed, B_longest_win_streak, B_losses, B_avg_opp_BODY_att, B_avg_opp_BODY_landed, B_avg_opp_CLINCH_att, B_avg_opp_CLINCH_landed, B_avg_opp_DISTANCE_att, B_avg_opp_DISTANCE_landed, B_avg_opp_GROUND_att, B_avg_opp_GROUND_landed, B_avg_opp_HEAD_att, B_avg_opp_HEAD_landed, B_avg_opp_KD, B_avg_opp_LEG_att, B_avg_opp_LEG_landed, B_avg_opp_PASS, B_avg_opp_REV, B_avg_opp_SIG_STR_att, B_avg_opp_SIG_STR_landed, B_avg_opp_SIG_STR_pct, B_avg_opp_SUB_ATT, B_avg_opp_TD_att, B_avg_opp_TD_landed, B_avg_opp_TD_pct, B_avg_opp_TOTAL_STR_att, B_avg_opp_TOTAL_STR_landed, B_total_rounds_fought, B_total_time_fought(seconds), B_total_title_bouts, B_win_by_Decision_Majority, B_win_by_Decision_Split, B_win_by_Decision_Unanimous, B_win_by_KO/TKO, B_win_by_Submission, B_win_by_TKO_Doctor_Stoppage, B_wins, B_Stance, B_Height_cms, B_Reach_cms, B_Weight_lbs, R_current_lose_streak, R_current_win_streak, R_avg_BODY_att, R_avg_BODY_landed, R_avg_CLINCH_att, R_avg_CLINCH_landed, R_avg_DISTANCE_att, R_avg_DISTANCE_landed, R_avg_GROUND_att, R_avg_GROUND_landed, R_avg_HEAD_att, R_avg_HEAD_landed, R_avg_KD, R_avg_LEG_att, R_avg_LEG_landed, R_avg_PASS, R_avg_REV, R_avg_SIG_STR_att, R_avg_SIG_STR_landed, R_avg_SIG_STR_pct, R_avg_SUB_ATT, R_avg_TD_att, R_avg_TD_landed, R_avg_TD_pct, R_avg_TOTAL_STR_att, ...]
# Index: []
#
# [0 rows x 145 columns]

# %%
# get fighter master data to the dataset
df_w_fighter = df_w_fighter.join(df_fighter.set_index('winner_fighter_name'), on="WinnerName")

# %%
df_w_fighter["WinningDate"] = df_w_fighter.date

# %%
df_w_fighter = df_w_fighter[["WinnerName", "WinnerAge", "winner_Height", "winner_Weight", "winner_Reach", "winner_Stance", "winner_DOB", "WinningDate", "title_bout"]]

# %%
df_w_fighter
# Out:
#                 WinnerName  WinnerAge  ... WinningDate title_bout
# 0             Henry Cejudo       32.0  ...  2019-06-08       True
# 1     Valentina Shevchenko       31.0  ...  2019-06-08       True
# 2            Tony Ferguson       35.0  ...  2019-06-08      False
# 3                 Petr Yan       26.0  ...  2019-06-08      False
# 4            Blagoy Ivanov       32.0  ...  2019-06-08      False
# 5           Tatiana Suarez       28.0  ...  2019-06-08      False
# 6        Aljamain Sterling       29.0  ...  2019-06-08      False
# 7             Alexa Grasso       25.0  ...  2019-06-08      False
# 8            Calvin Kattar       31.0  ...  2019-06-08      False
# ...                    ...        ...  ...         ...        ...
# 5121          Royce Gracie       27.0  ...  1994-03-11       True
# 5122          Royce Gracie       27.0  ...  1994-03-11      False
# 5123         Patrick Smith       30.0  ...  1994-03-11      False
# 5124          Royce Gracie       27.0  ...  1994-03-11      False
# 5125         Remco Pardoel       30.0  ...  1994-03-11      False
# 5127         Patrick Smith       30.0  ...  1994-03-11      False
# 5136          Royce Gracie       26.0  ...  1993-11-12       True
# 5138          Royce Gracie       26.0  ...  1993-11-12      False
# 5139        Gerard Gordeau       34.0  ...  1993-11-12      False
#
# [3592 rows x 9 columns]

# %% [markdown]
# ### Drop columns
# It looks like Fighter names, Referees, dates and location should not influence the prediction and statistics

# %%
df = df.drop(["R_fighter", "B_fighter", "Referee", "date", "location"], axis=1)

# %%
df.dtypes
# Out:
# Winner                           object
# title_bout                         bool
# weight_class                     object
# no_of_rounds                      int64
# B_current_lose_streak           float64
# B_current_win_streak            float64
# B_avg_BODY_att                  float64
# B_avg_BODY_landed               float64
# B_avg_CLINCH_att                float64
# B_avg_CLINCH_landed             float64
# B_avg_DISTANCE_att              float64
# B_avg_DISTANCE_landed           float64
#                                  ...
# R_win_by_Decision_Split         float64
# R_win_by_Decision_Unanimous     float64
# R_win_by_KO/TKO                 float64
# R_win_by_Submission             float64
# R_win_by_TKO_Doctor_Stoppage    float64
# R_wins                          float64
# R_Stance                         object
# R_Height_cms                    float64
# R_Reach_cms                     float64
# R_Weight_lbs                    float64
# B_age                           float64
# R_age                           float64
# Length: 138, dtype: object

# %% [markdown]
# ## Write clean files

# %%
df.to_csv("../data/clean/UFC-cleaned.csv", index=False)

# %%
df_w_fighter.to_csv("../data/clean/UFC-cleaned-with-fighternames.csv", index=False)
