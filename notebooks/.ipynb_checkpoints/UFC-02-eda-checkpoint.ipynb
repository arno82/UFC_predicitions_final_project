# %% [markdown]
# # EDA

# %%
import pandas as pd
import plotly.express as px
import plotly
import numpy as np
import plotly.graph_objects as go
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import pickle
from sklearn.ensemble import RandomForestClassifier
from  sklearn.preprocessing import OrdinalEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from  sklearn.metrics import *
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn import model_selection
import rfpimp
import re

# %%
pictureFolderOutput = "../resources/"

# %%
df = pd.read_csv("../data/clean/UFC-cleaned.csv", sep=",")

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 0)

# %%
df.head()
# Out:
#   Winner  title_bout  ... WinnerAge  WinningDate
# 0    Red        True  ...      32.0   2019-06-08
# 1    Red        True  ...      31.0   2019-06-08
# 2    Red       False  ...      35.0   2019-06-08
# 3   Blue       False  ...      26.0   2019-06-08
# 4   Blue       False  ...      32.0   2019-06-08
#
# [5 rows x 141 columns]

# %% [markdown]
# # Feature Exploration
# 1. Correlations
#     1. All metrics
#     1. Reduced metrics
# 1. Compare predictions quality for both
# 1. Prediction

# %% [markdown]
# ## Overall Statistic

# %% [markdown]
# for column in df.columns:
#     print('Statistic for', column)
#     print(df[column].describe())
#     print('---------------------')

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Correlation for all metrics

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix.head()
# Out:
#                        title_bout  no_of_rounds  ...     R_age  WinnerAge
# title_bout               1.000000      0.637445  ...  0.018817   0.042907
# no_of_rounds             0.637445      1.000000  ...  0.091420   0.112909
# B_current_lose_streak   -0.143853     -0.107887  ...  0.011790   0.069241
# B_current_win_streak     0.316009      0.302900  ...  0.064624   0.019999
# B_avg_BODY_att          -0.006543      0.080438  ...  0.053674  -0.000338
#
# [5 rows x 135 columns]

# %%
fig = go.Figure(data=go.Heatmap(x=correlation_matrix.columns, y=correlation_matrix.columns,z=correlation_matrix))
fig.show()

# %% [markdown]
# Printing a correlation matrix with so many features doesn't make sense.

# %% [markdown]
# ### Get highest correlations
# from https://stackoverflow.com/questions/17778394/list-highest-correlation-pairs-from-a-large-correlation-matrix-in-pandas

# %%
def show_high_corr(df_input):
    corr_matrix = df_input.corr().abs()
    #the matrix is symmetric so we need to extract upper triangle matrix without diagonal (k = 1)
    sol = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
                     .stack()
                     .sort_values(ascending=False))
    #first element of sol series is the pair with the bigest correlation
    return sol

# %%
sol = show_high_corr(df)
sol.head(50)
# Out:
# R_avg_opp_HEAD_att         R_avg_opp_SIG_STR_att        0.984553
# B_avg_opp_HEAD_att         B_avg_opp_SIG_STR_att        0.982878
# B_avg_HEAD_att             B_avg_SIG_STR_att            0.979632
# B_avg_LEG_att              B_avg_LEG_landed             0.979291
# R_avg_HEAD_att             R_avg_SIG_STR_att            0.978031
# B_avg_opp_LEG_att          B_avg_opp_LEG_landed         0.977537
# R_avg_LEG_att              R_avg_LEG_landed             0.976025
# R_avg_opp_LEG_att          R_avg_opp_LEG_landed         0.972444
# R_avg_opp_DISTANCE_att     R_avg_opp_SIG_STR_att        0.971328
# R_avg_CLINCH_att           R_avg_CLINCH_landed          0.969919
# R_avg_GROUND_att           R_avg_GROUND_landed          0.969339
# B_avg_CLINCH_att           B_avg_CLINCH_landed          0.968278
# B_avg_opp_DISTANCE_att     B_avg_opp_SIG_STR_att        0.967814
# B_avg_opp_CLINCH_att       B_avg_opp_CLINCH_landed      0.966826
# R_avg_opp_CLINCH_att       R_avg_opp_CLINCH_landed      0.964298
# B_avg_GROUND_att           B_avg_GROUND_landed          0.963844
# B_avg_DISTANCE_att         B_avg_SIG_STR_att            0.962988
# R_avg_opp_GROUND_att       R_avg_opp_GROUND_landed      0.962905
# B_avg_opp_GROUND_att       B_avg_opp_GROUND_landed      0.962145
# R_avg_DISTANCE_att         R_avg_SIG_STR_att            0.961707
# R_avg_BODY_att             R_avg_BODY_landed            0.960236
# R_avg_opp_DISTANCE_att     R_avg_opp_HEAD_att           0.957571
# B_avg_BODY_att             B_avg_BODY_landed            0.957379
# B_avg_opp_DISTANCE_att     B_avg_opp_HEAD_att           0.954122
# R_avg_opp_BODY_att         R_avg_opp_BODY_landed        0.953070
# B_avg_opp_BODY_att         B_avg_opp_BODY_landed        0.952653
# B_avg_DISTANCE_att         B_avg_HEAD_att               0.948269
# R_avg_DISTANCE_att         R_avg_HEAD_att               0.943140
# B_avg_DISTANCE_att         B_avg_DISTANCE_landed        0.941493
# R_avg_DISTANCE_att         R_avg_DISTANCE_landed        0.936984
# R_avg_opp_HEAD_landed      R_avg_opp_SIG_STR_landed     0.936701
# R_avg_opp_DISTANCE_att     R_avg_opp_DISTANCE_landed    0.936060
# B_Weight_lbs               R_Weight_lbs                 0.934506
# B_avg_opp_DISTANCE_att     B_avg_opp_DISTANCE_landed    0.934262
# B_avg_opp_HEAD_landed      B_avg_opp_SIG_STR_landed     0.932631
# R_avg_opp_SIG_STR_att      R_avg_opp_TOTAL_STR_att      0.929127
# B_avg_HEAD_landed          B_avg_SIG_STR_landed         0.927567
# B_avg_opp_SIG_STR_att      B_avg_opp_TOTAL_STR_att      0.925122
# B_avg_SIG_STR_att          B_avg_SIG_STR_landed         0.923991
# R_avg_HEAD_landed          R_avg_SIG_STR_landed         0.920995
# R_avg_opp_DISTANCE_landed  R_avg_opp_SIG_STR_att        0.919878
#                            R_avg_opp_SIG_STR_landed     0.918359
# R_avg_opp_SIG_STR_att      R_avg_opp_SIG_STR_landed     0.918110
# B_total_rounds_fought      B_wins                       0.917830
# R_total_rounds_fought      R_wins                       0.917245
# B_avg_opp_DISTANCE_landed  B_avg_opp_SIG_STR_att        0.915822
# B_avg_opp_SIG_STR_att      B_avg_opp_SIG_STR_landed     0.914031
# B_avg_SIG_STR_att          B_avg_TOTAL_STR_att          0.912625
# R_avg_SIG_STR_att          R_avg_TOTAL_STR_att          0.912044
#                            R_avg_SIG_STR_landed         0.911625
# dtype: float64

# %% [markdown]
# Many unnecessary correlations found...
# Also attempts and landed should be combined into one percentage to reduce features.

# %% [markdown]
# ## Correlation with reduced metrics

# %% [markdown]
# ### Calculate landed percentage
# 1. Sort columns by name
# 1. Divide landed / attempts
# 1. Drop the landed and attempts columns

# %%
df2 = df.reindex(sorted(df.columns), axis=1)

# %%
# check if _att comes before _landed. Compare prefixes to be sure to have the correct values
for i in df2.columns:
    if re.search(".*_att", i):
        att_save = i[:-4] #first part of the keyword
        att_value_save = df2[i] #value of the column for later use
        continue
    if re.search(".*_landed", i) and (i[:-7] == att_save): # found landed, compare the first part of the key if landed and att match
        df2[att_save+"_pct"] = df2[i] / att_value_save
        df2[att_save+"_pct"] = df2[att_save+"_pct"].fillna(0)
        att_save = ""

# %%
df2 = df2.reindex(sorted(df2.columns), axis=1)
df2
# Out:
#       B_Height_cms  B_Reach_cms  ... title_bout       weight_class
# 0           167.64       170.18  ...       True       Bantamweight
# 1           167.64       167.64  ...       True  Women's Flyweight
# 2           185.42       185.42  ...      False        Lightweight
# 3           170.18       170.18  ...      False       Bantamweight
# 4           180.34       185.42  ...      False        Heavyweight
# ...            ...          ...  ...        ...                ...
# 3587        177.80       177.80  ...      False        Open Weight
# 3588        177.80       177.80  ...      False        Open Weight
# 3589        195.58       195.58  ...       True       Catch Weight
# 3590        185.42       182.88  ...      False        Open Weight
# 3591        193.04       193.04  ...      False        Open Weight
#
# [3592 rows x 169 columns]

# %%
# now drop _att and _landed columns if the pct columns is found afterwards
drop_columns = []
for i in df2.columns:
#    print(i)
    if re.search(".*_att", i):
        att_save_pre = i[:-4]
        att_save = i
        continue
    if re.search(".*_landed", i) and (i[:-7] == att_save_pre):
        landed_save_pre = i[:-7]
        landed_save = i
        continue
    if re.search(".*_pct", i) and (i[:-4] == att_save_pre) and (i[:-4] == landed_save_pre):
        df3 = df2.drop([att_save, landed_save], axis=1)
        drop_columns.append(att_save)
        drop_columns.append(landed_save)
        att_save = ""
        landed_save = ""
df2.drop(drop_columns, axis=1, inplace=True)

# %% [markdown]
# ### Reduced correlation matrix

# %% [markdown]
# df.drop('', axis=1, inplace=true)

# %%
correlation_matrix = df2.corr()
fig = go.Figure(data=go.Heatmap(x=correlation_matrix.columns, y=correlation_matrix.columns,z=correlation_matrix))
fig.show()

# %%
sol = show_high_corr(df2)
sol.head(50)
# Out:
# B_Weight_lbs                 R_Weight_lbs                   0.934506
# B_total_rounds_fought        B_wins                         0.917830
# R_total_rounds_fought        R_wins                         0.917245
# R_Height_cms                 R_Reach_cms                    0.894118
# R_avg_HEAD_pct               R_avg_SIG_STR_pct              0.892208
# B_Height_cms                 B_Reach_cms                    0.883699
# B_avg_HEAD_pct               B_avg_SIG_STR_pct              0.862440
# R_avg_opp_HEAD_pct           R_avg_opp_SIG_STR_pct          0.859776
# B_longest_win_streak         B_wins                         0.838802
# B_losses                     B_total_rounds_fought          0.825168
# B_avg_opp_HEAD_pct           B_avg_opp_SIG_STR_pct          0.823150
# R_longest_win_streak         R_wins                         0.813536
# B_avg_opp_SIG_STR_pct        B_avg_opp_TOTAL_STR_pct        0.806160
# R_losses                     R_total_rounds_fought          0.802834
# R_avg_SIG_STR_pct            R_avg_TOTAL_STR_pct            0.791625
# R_Height_cms                 R_Weight_lbs                   0.787152
# B_avg_SIG_STR_pct            B_avg_TOTAL_STR_pct            0.782545
# B_Height_cms                 B_Weight_lbs                   0.780543
# R_avg_opp_SIG_STR_pct        R_avg_opp_TOTAL_STR_pct        0.780537
# R_total_rounds_fought        R_win_by_Decision_Unanimous    0.774615
# B_total_rounds_fought        B_win_by_Decision_Unanimous    0.772132
# B_Weight_lbs                 R_Height_cms                   0.756459
# B_Height_cms                 R_Weight_lbs                   0.754079
# B_win_by_KO/TKO              B_wins                         0.749336
# R_win_by_Decision_Unanimous  R_wins                         0.744684
# R_Reach_cms                  R_Weight_lbs                   0.740269
# B_win_by_Decision_Unanimous  B_wins                         0.737024
# R_avg_HEAD_pct               R_avg_TOTAL_STR_pct            0.731656
# R_win_by_KO/TKO              R_wins                         0.728152
# B_Reach_cms                  B_Weight_lbs                   0.719890
# B_Height_cms                 R_Height_cms                   0.715756
# R_age                        WinnerAge                      0.710165
# B_Weight_lbs                 R_Reach_cms                    0.709571
# B_Reach_cms                  R_Weight_lbs                   0.702696
# B_longest_win_streak         B_total_rounds_fought          0.691975
# B_Height_cms                 R_Reach_cms                    0.682373
# B_avg_opp_DISTANCE_pct       B_avg_opp_SIG_STR_pct          0.678404
# B_Reach_cms                  R_Height_cms                   0.675729
# R_avg_opp_DISTANCE_pct       R_avg_opp_SIG_STR_pct          0.675703
# B_avg_HEAD_pct               B_avg_TOTAL_STR_pct            0.675463
# R_longest_win_streak         R_total_rounds_fought          0.673720
# R_avg_opp_HEAD_pct           R_avg_opp_TOTAL_STR_pct        0.670639
# B_longest_win_streak         B_win_by_KO/TKO                0.664135
# B_avg_opp_HEAD_pct           B_avg_opp_TOTAL_STR_pct        0.659616
# B_Reach_cms                  R_Reach_cms                    0.657203
# B_losses                     B_wins                         0.655344
# R_avg_DISTANCE_pct           R_avg_SIG_STR_pct              0.644340
# R_losses                     R_wins                         0.641761
# no_of_rounds                 title_bout                     0.637445
# R_longest_win_streak         R_win_by_Decision_Unanimous    0.623813
# dtype: float64

# %% [markdown]
# The chart is still not usable, but the table is.
# We still see a lot of unneccessary correlations like B_Weight_lbs and R_Weight_lbs which is obvious because they fight in the same weight classes.

# %% [markdown]
# ## Compare predictions

# %% [markdown]
# ### Define categories for one hot encoding
# df and df2 are equal in this point

# %%
df.B_Stance.value_counts()
# Out:
# Orthodox       2762
# Southpaw        709
# Switch          114
# Open Stance       5
# Sideways          2
# Name: B_Stance, dtype: int64

# %%
df.R_Stance.value_counts()
# Out:
# Orthodox       2724
# Southpaw        757
# Switch           99
# Open Stance      12
# Name: R_Stance, dtype: int64

# %%
df.weight_class.value_counts()
# Out:
# Lightweight              703
# Welterweight             696
# Middleweight             518
# Light Heavyweight        361
# Heavyweight              327
# Featherweight            321
# Bantamweight             265
# Flyweight                141
# Women's Strawweight       98
# Women's Bantamweight      71
# Open Weight               35
# Women's Flyweight         29
# Catch Weight              23
# Women's Featherweight      4
# Name: weight_class, dtype: int64

# %% [markdown]
# Weight_class and stances should be categories

# %%
categorical_columns = ["Winner", "weight_class", "B_Stance", "R_Stance"]

# %%
for col in categorical_columns:
    df[col] = df[col].astype('category')
    df2[col] = df2[col].astype('category')

# %%
df = pd.get_dummies(df, drop_first=True)
df2 = pd.get_dummies(df2, drop_first=True)

# %% [markdown]
# ### Random Forest - Reduced

# %%
X = df2.drop('Winner_Red', axis=1)
y = df2.Winner_Red

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_scores = cross_validate(rfc, X, y.values.ravel(), cv=5, scoring=('accuracy', 'average_precision', 'recall','f1'))
rfc_scores
# Out:
# {'fit_time': array([2.08499956, 1.78300142, 1.69802284, 1.71299362, 1.85200572]),
#  'score_time': array([0.16900134, 0.1259985 , 0.12897396, 0.12700415, 0.13102674]),
#  'test_accuracy': array([0.6689847 , 0.67872045, 0.66991643, 0.67130919, 0.66713092]),
#  'test_average_precision': array([0.74973347, 0.74074603, 0.71529645, 0.78847889, 0.73927543]),
#  'test_recall': array([0.82563025, 0.91386555, 0.95378151, 0.98109244, 1.        ]),
#  'test_f1': array([0.76757812, 0.79019074, 0.7930131 , 0.7982906 , 0.7993283 ])}

# %% [markdown]
# ### Random Forest - Full

# %%
X = df.drop('Winner_Red', axis=1)
y = df.Winner_Red

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_scores = cross_validate(rfc, X, y.values.ravel(), cv=5, scoring=('accuracy', 'average_precision', 'recall','f1'))
rfc_scores
# Out:
# {'fit_time': array([1.75002933, 1.6830287 , 1.6849947 , 1.76999259, 1.79197145]),
#  'score_time': array([0.12996578, 0.12701488, 0.13196206, 0.12401724, 0.12702918]),
#  'test_accuracy': array([0.6147427 , 0.66342142, 0.65041783, 0.68245125, 0.66852368]),
#  'test_average_precision': array([0.72597442, 0.7318545 , 0.73227778, 0.81297746, 0.78038729]),
#  'test_recall': array([0.73739496, 0.87394958, 0.89705882, 0.96638655, 0.99579832]),
#  'test_f1': array([0.71705822, 0.77467412, 0.77285068, 0.80139373, 0.79932546])}

# %% [markdown]
# ## Prediction conclusion

# %% [markdown]
# ### Data decision
# The scores between df and df2 aren't really different, so we can move on with the full dataset. Dismiss df2.

# %% [markdown]
# The prediction accuracy is only around 60% to 70%, which is pretty useless.

# %% [markdown]
# importance = rfpimp.importances(rfc, X_test, y_test)

# %% [markdown]
# importance

# %% [markdown]
# ### Save the model and data

# %%
pickle.dump(rfc, open('../models/rfc.model', 'wb'))

# %%
df.to_csv("../data/clean/UFC-processed.csv", index=False)

# %% [markdown]
# ## Everything about the winners

# %%
df_w_fighter = pd.read_csv("../data/clean/UFC-cleaned-with-fighternames.csv")

# %%
df_w_fighter
# Out:
#                 WinnerName  WinnerAge  ... WinningDate title_bout
# 0             Henry Cejudo       32.0  ...  2019-06-08       True
# 1     Valentina Shevchenko       31.0  ...  2019-06-08       True
# 2            Tony Ferguson       35.0  ...  2019-06-08      False
# 3                 Petr Yan       26.0  ...  2019-06-08      False
# 4            Blagoy Ivanov       32.0  ...  2019-06-08      False
# ...                    ...        ...  ...         ...        ...
# 3587         Remco Pardoel       30.0  ...  1994-03-11      False
# 3588         Patrick Smith       30.0  ...  1994-03-11      False
# 3589          Royce Gracie       26.0  ...  1993-11-12       True
# 3590          Royce Gracie       26.0  ...  1993-11-12      False
# 3591        Gerard Gordeau       34.0  ...  1993-11-12      False
#
# [3592 rows x 9 columns]

# %% [markdown]
# ### Most wins

# %%
def createTopWinners():
    mostwinners = []
    mostwinners = df_w_fighter.groupby("WinnerName").count().reset_index()
    #just create a dummy for the counts
    mostwinners["Wins"] = mostwinners.WinningDate
    mostwinners = mostwinners[["WinnerName", "Wins"]]
    mostwinners = mostwinners.sort_values(by="Wins", ascending=False)
    return mostwinners

# %%
mostwinners = createTopWinners()
mostwinners.head(10)
# Out:
#             WinnerName  Wins
# 621    Michael Bisping    19
# 246     Donald Cerrone    19
# 226        Demian Maia    18
# 727   Rafael Dos Anjos    18
# 449          Jon Jones    17
# 320  Georges St-Pierre    17
# 416         Jim Miller    16
# 45      Anderson Silva    16
# 329      Gleison Tibau    15
# 303      Frankie Edgar    15

# %%
fig = px.bar(mostwinners.head(10).sort_values(by="Wins"), y="WinnerName", x="Wins", orientation="h", title="Most fights won")
fig = fig.update_yaxes(title_text='')
fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False)
fig.write_image(pictureFolderOutput + "MostFightsWon.png")
fig.show()

# %% [markdown]
# ### Age of winners

# %%
fig = px.histogram(df_w_fighter, x="WinnerAge", title="Age of winners")
fig = fig.update_xaxes(title_text='Age')
fig = fig.update_yaxes(title_text='')
fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False)
fig.write_image(pictureFolderOutput + "WinnersAge.png")
fig.show()

# %% [markdown]
# ### Most title fights won

# %%
df_w_fighter = df_w_fighter[df_w_fighter.title_bout == True]

# %%
mostwinners = createTopWinners()
mostwinners.head(10)
# Out:
#             WinnerName  Wins
# 31   Georges St-Pierre    13
# 42           Jon Jones    12
# 20  Demetrious Johnson    12
# 1       Anderson Silva    11
# 70       Randy Couture    10
# 57         Matt Hughes     7
# 43           Jose Aldo     7
# 85          Tito Ortiz     6
# 40  Joanna Jedrzejczyk     6
# 19      Daniel Cormier     6

# %%
fig = px.bar(mostwinners.head(10).sort_values(by="Wins"), y="WinnerName", x="Wins", orientation="h", title="Most title fights won")
fig = fig.update_yaxes(title_text='')
fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False)
fig.write_image(pictureFolderOutput + "MostTitleFightsWon.png")
fig.show()
